# %% [markdown]
# # GCN

# %% [markdown]
# ### Installs

# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Mounted at /content/gdrive/

# %%
# !pip install sentence-transformers
# !pip install rdflib
import os
import torch
os.environ['TORCH'] = torch.__version__
print(torch.__version__)

# !pip install -q torch-scatter -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install -q torch-sparse -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install -q git+https://github.com/pyg-team/pytorch_geometric.git

! pip install torchmetrics

# %% [markdown]
# ### Imports

# %%
import torch.nn.functional as F
import os
import torch
import numpy as np
import random


from typing import List, Callable

from torch import Tensor, device
import pandas as pd

# %%
os.chdir("/content/gdrive/My Drive/1_Studium/2_Master/Master Thesis/2_Projekt/Scratch/all_in/MAGNET")

# %%
from torch_geometric.nn import GATConv, GCNConv, RGATConv

# %%
import model_functions.helper_funcs as helper_funcs
import model_functions.model_definitions as model_definition
import model_functions.losses as losses_funcs
import math
import random
import numpy as np

# %%
class GCNClassic(torch.nn.Module):
    def __init__(self, num_node_features):
        super().__init__()
        self.conv1_one = GCNConv(num_node_features, num_node_features)
        self.conv1_two = GCNConv(num_node_features, num_node_features)

    def forward(self, data):

        x_one, edge_index_one = data['x_one'], data['edge_index_one']
        x_one = self.conv1_one(x_one, edge_index_one).relu()
        x_one = F.dropout(x_one, training=self.training)

        x_two, edge_index_two = data['x_two'], data['edge_index_two']
        x_two = self.conv1_two(x_two, edge_index_two).relu()
        x_two = F.dropout(x_two, training=self.training)
        return x_one, x_two

# %% [markdown]
# Data

# %%
os.chdir("/content/gdrive/My Drive/1_Studium/2_Master/Master Thesis/2_Projekt/Scratch/all_in/data")
use_case = "anatomy_diff"
a_or_b = "case_a"
data = torch.load(use_case +  "/" + a_or_b + ".pt")

# %%
#double_left_tensor, double_right_tensor = create_fake_data(data.train_set_right, data.train_set_left)
#torch.save(double_left_tensor, preprocessed_data_path+"/"+use_case+"/double_left_tensor.pt")
#torch.save(double_right_tensor, preprocessed_data_path+"/"+use_case+"/double_right_tensor.pt")
#double_left_tensor = torch.load(preprocessed_data_path+"/"+use_case+"/a/double_left_tensor.pt")
#double_right_tensor = torch.load(preprocessed_data_path+"/"+use_case+"/a/double_right_tensor.pt")

# %%
double_left_tensor, double_right_tensor = helper_funcs.create_fake_data(data.train_set_right, data.train_set_left)

# %% [markdown]
# ###Functions for new loss

# %%
class CosineSimilarityLoss4(torch.nn.Module):
    def __init__(self, model):
        super().__init__()
        self.model = model
        self.loss_fct = torch.nn.MSELoss()
    
    def forward(self, data, lefts, rights):
        x_one, x_two = self.model(data)
        
        left_embeddings = torch.index_select(x_one, 0, lefts)
        right_embeddings = torch.index_select(x_two, 0, rights)
        length_of_anti_alignments = len(lefts) - (len(data.train_set_left)) 
        print("len of anti-alignments: ", length_of_anti_alignments)


        
        output = torch.cosine_similarity(left_embeddings, right_embeddings)

        if length_of_anti_alignments == 0:
          return self.loss_fct(output, torch.ones(int(len((data.train_set_left)))))
        else:
          return self.loss_fct(output, torch.cat(((torch.ones(int(len(data.train_set_left))),
                                                 torch.zeros(int(length_of_anti_alignments)))))) # negatives

# %%
def create_anti_alignment(epoch, matches):

  # Check, if wrong matches exist to train the model with
  lefts, rights, wrong_set_left, wrong_set_right = helper_funcs.filter_out_wrong_matches(matches, data)
  max_length = len(data.train_set_right)

  if len(wrong_set_left) > 0:
    
    # Create mixed version of anti-alignments

    # 1. Create the proportions
    prop_model = epoch / 1000
    proportion_of_model_faults = math.floor(prop_model * 100)/100.0
    proportion_of_model_random = 1 - proportion_of_model_faults
    #print('prop model: ' , proportion_of_model_faults)
    #print('prop random: ' , proportion_of_model_random)

    # 2. Choose wrong examples from model proportionately
    count_of_model_faults = math.floor(proportion_of_model_faults * max_length) # calculation, how many examples are considered
    #print("count_of_model_faults", count_of_model_faults)
    #chosen_indices = [random.randint(0, len(wrong_set_left)) for x in range(count_of_model_faults)]
    amount_that_can_be_chosen = min(count_of_model_faults, len(wrong_set_right))
    chosen_indices = random.sample(range(len(wrong_set_right)), amount_that_can_be_chosen)
    #print("chosen_indices", chosen_indices)
    picked_left = list(np.array(wrong_set_left)[chosen_indices])
    picked_right = list(np.array(wrong_set_right)[chosen_indices])
    #print('picked_left: ', picked_left)
    #print('picked_left: ', picked_right)

    # 3. Create random anti-alignments
    
    random_length = round(proportion_of_model_random * max_length)
    #print('random length', random_length)
    m = max(data.train_set_right.tolist()) # max value of mapped_to
    complete_list = list(np.arange(0, m))
    non_commoners = list(set(complete_list) ^ set(data.train_set_right.tolist()))
    wrong_right_indices = [random.choice(non_commoners) for x in range(0, (random_length))]
    #print('len of random anti alignments: ', len(wrong_right_indices))

    # 4. Pack it all together 

    # First part is the true alignment, then the random alignment and then the model-generated faults
    lefts = torch.cat((data.train_set_left, data.train_set_left[:len(wrong_right_indices)], torch.tensor(picked_left)), 0)
    rights = torch.cat((data.train_set_right, torch.tensor(wrong_right_indices), torch.tensor(picked_right)), 0)

    lefts = lefts.type(torch.int64)
    rights = rights.type(torch.int64)
    return lefts, rights
  
  # In the case that no model output exists yet, only the random version happens   
  else:
    lefts, rights = helper_funcs.create_fake_data(data.train_set_right, data.train_set_left)
    return lefts, rights

# %%
def create_anti_alignment_more_random(epoch, matches):

  # Check, if wrong matches exist to train the model with
  lefts, rights, wrong_set_left, wrong_set_right = helper_funcs.filter_out_wrong_matches(matches, data)
  max_length = len(data.train_set_right)

  if len(wrong_set_left) > 0:
    
    # Create mixed version of anti-alignments

    # 1. Create the proportions
    prop_model = epoch / 2000
    proportion_of_model_faults = math.floor(prop_model * 100)/100.0
    proportion_of_model_random = 1 - proportion_of_model_faults
    #print('prop model: ' , proportion_of_model_faults)
    #print('prop random: ' , proportion_of_model_random)

    # 2. Choose wrong examples from model proportionately
    count_of_model_faults = math.floor(proportion_of_model_faults * max_length) # calculation, how many examples are considered
    #print("count_of_model_faults", count_of_model_faults)
    #chosen_indices = [random.randint(0, len(wrong_set_left)) for x in range(count_of_model_faults)]
    amount_that_can_be_chosen = min(count_of_model_faults, len(wrong_set_right))
    chosen_indices = random.sample(range(len(wrong_set_right)), amount_that_can_be_chosen)
    #print("chosen_indices", chosen_indices)
    picked_left = list(np.array(wrong_set_left)[chosen_indices])
    picked_right = list(np.array(wrong_set_right)[chosen_indices])
    #print('picked_left: ', picked_left)
    #print('picked_left: ', picked_right)

    # 3. Create random anti-alignments
    
    random_length = round(proportion_of_model_random * max_length)
    #print('random length', random_length)
    m = max(data.train_set_right.tolist()) # max value of mapped_to
    complete_list = list(np.arange(0, m))
    non_commoners = list(set(complete_list) ^ set(data.train_set_right.tolist()))
    wrong_right_indices = [random.choice(non_commoners) for x in range(0, (random_length))]
    #print('len of random anti alignments: ', len(wrong_right_indices))

    # 4. Pack it all together 

    # First part is the true alignment, then the random alignment and then the model-generated faults
    lefts = torch.cat((data.train_set_left, data.train_set_left[:len(wrong_right_indices)], torch.tensor(picked_left)), 0)
    rights = torch.cat((data.train_set_right, torch.tensor(wrong_right_indices), torch.tensor(picked_right)), 0)

    lefts = lefts.type(torch.int64)
    rights = rights.type(torch.int64)
    return lefts, rights
  
  # In the case that no model output exists yet, only the random version happens   
  else:
    lefts, rights = helper_funcs.create_fake_data(data.train_set_right, data.train_set_left)
    return lefts, rights

# %%
def create_anti_alignment_model_faults_first(epoch, matches):

  # Check, if wrong matches exist to train the model with
  lefts, rights, wrong_set_left, wrong_set_right = helper_funcs.filter_out_wrong_matches(matches, data)
  max_length = len(data.train_set_right)

  if len(wrong_set_left) > 0:
    
    # Create mixed version of anti-alignments

    # 1. Create the proportions
    prop_random = epoch / 1000
    proportion_of_model_random = math.floor(prop_random * 100)/100.0
    proportion_of_model_faults = 1 - proportion_of_model_random


    # 2. Create random anti-alignments
    
    random_length = round(proportion_of_model_random * max_length)
    #print('random length', random_length)
    m = max(data.train_set_right.tolist()) # max value of mapped_to
    complete_list = list(np.arange(0, m))
    non_commoners = list(set(complete_list) ^ set(data.train_set_right.tolist()))
    wrong_right_indices = [random.choice(non_commoners) for x in range(0, (random_length))]
    #print('len of random anti alignments: ', len(wrong_right_indices))

    # 3. Choose wrong examples from model proportionately
    count_of_model_faults = math.floor(proportion_of_model_faults * max_length) # calculation, how many examples are considered
    #print("count_of_model_faults", count_of_model_faults)
    #chosen_indices = [random.randint(0, len(wrong_set_left)) for x in range(count_of_model_faults)]
    amount_that_can_be_chosen = min(count_of_model_faults, len(wrong_set_right))
    chosen_indices = random.sample(range(len(wrong_set_right)), amount_that_can_be_chosen)
    #print("chosen_indices", chosen_indices)
    picked_left = list(np.array(wrong_set_left)[chosen_indices])
    picked_right = list(np.array(wrong_set_right)[chosen_indices])
    #print('picked_left: ', picked_left)
    #print('picked_left: ', picked_right)


    # 4. Pack it all together 

    # First part is the true alignment, then the random alignment and then the model-generated faults
    lefts = torch.cat((data.train_set_left, data.train_set_left[:len(wrong_right_indices)], torch.tensor(picked_left)), 0)
    rights = torch.cat((data.train_set_right, torch.tensor(wrong_right_indices), torch.tensor(picked_right)), 0)

    lefts = lefts.type(torch.int64)
    rights = rights.type(torch.int64)
    return lefts, rights
  
  # In the case that no model output exists yet, no additional loss happens
  else:
    return data.train_set_left, data.train_set_right

# %%
def create_anti_alignment_model_faults_first_other_proportions(epoch, matches):

  # Check, if wrong matches exist to train the model with
  lefts, rights, wrong_set_left, wrong_set_right = helper_funcs.filter_out_wrong_matches(matches, data)
  max_length = len(data.train_set_right)

  if len(wrong_set_left) > 0:
    
    # Create mixed version of anti-alignments

    # 1. Create the proportions
    prop_random = epoch / 2000
    proportion_of_model_random = math.floor(prop_random * 100)/100.0
    proportion_of_model_faults = 1 - proportion_of_model_random


    # 2. Create random anti-alignments
    
    random_length = round(proportion_of_model_random * max_length)
    #print('random length', random_length)
    m = max(data.train_set_right.tolist()) # max value of mapped_to
    complete_list = list(np.arange(0, m))
    non_commoners = list(set(complete_list) ^ set(data.train_set_right.tolist()))
    wrong_right_indices = [random.choice(non_commoners) for x in range(0, (random_length))]
    #print('len of random anti alignments: ', len(wrong_right_indices))

    # 3. Choose wrong examples from model proportionately
    count_of_model_faults = math.floor(proportion_of_model_faults * max_length) # calculation, how many examples are considered
    #print("count_of_model_faults", count_of_model_faults)
    #chosen_indices = [random.randint(0, len(wrong_set_left)) for x in range(count_of_model_faults)]
    amount_that_can_be_chosen = min(count_of_model_faults, len(wrong_set_right))
    chosen_indices = random.sample(range(len(wrong_set_right)), amount_that_can_be_chosen)
    #print("chosen_indices", chosen_indices)
    picked_left = list(np.array(wrong_set_left)[chosen_indices])
    picked_right = list(np.array(wrong_set_right)[chosen_indices])
    #print('picked_left: ', picked_left)
    #print('picked_left: ', picked_right)


    # 4. Pack it all together 

    # First part is the true alignment, then the random alignment and then the model-generated faults
    lefts = torch.cat((data.train_set_left, data.train_set_left[:len(wrong_right_indices)], torch.tensor(picked_left)), 0)
    rights = torch.cat((data.train_set_right, torch.tensor(wrong_right_indices), torch.tensor(picked_right)), 0)

    lefts = lefts.type(torch.int64)
    rights = rights.type(torch.int64)
    return lefts, rights
  
  # In the case that no model output exists yet, no additional loss happens
  else:
    return data.train_set_left, data.train_set_right

# %%
def create_anti_alignment_v43_2000(epoch, matches, data):
    # Check, if wrong matches exist to train the model with
    lefts, rights, wrong_set_left, wrong_set_right = helper_funcs.filter_out_wrong_matches(matches, data)
    max_length = len(data.train_set_right)

    if len(wrong_set_left) > 0:
      if epoch <= 1000:


        # Create mixed version of anti-alignments

        # 1. Create the proportions
        prop_random = epoch / 1000
        proportion_of_model_random = math.floor(prop_random * 100) / 100.0
        proportion_of_model_faults = 1 - proportion_of_model_random

        # 2. Create random anti-alignments

        random_length = round(proportion_of_model_random * max_length)
        # print('random length', random_length)
        m = max(data.train_set_right.tolist())  # max value of mapped_to
        complete_list = list(np.arange(0, m))
        non_commoners = list(set(complete_list) ^ set(data.train_set_right.tolist()))
        wrong_right_indices = [random.choice(non_commoners) for x in range(0, (random_length))]
        # print('len of random anti alignments: ', len(wrong_right_indices))

        # 3. Choose wrong examples from model proportionately
        count_of_model_faults = math.floor(
            proportion_of_model_faults * max_length)  # calculation, how many examples are considered
        # print("count_of_model_faults", count_of_model_faults)
        # chosen_indices = [random.randint(0, len(wrong_set_left)) for x in range(count_of_model_faults)]
        amount_that_can_be_chosen = min(count_of_model_faults, len(wrong_set_right))
        chosen_indices = random.sample(range(len(wrong_set_right)), amount_that_can_be_chosen)
        # print("chosen_indices", chosen_indices)
        picked_left = list(np.array(wrong_set_left)[chosen_indices])
        picked_right = list(np.array(wrong_set_right)[chosen_indices])
        # print('picked_left: ', picked_left)
        # print('picked_left: ', picked_right)

        # 4. Pack it all together

        # First part is the true alignment, then the random alignment and then the model-generated faults
        lefts = torch.cat(
            (data.train_set_left, data.train_set_left[:len(wrong_right_indices)], torch.tensor(picked_left)), 0)
        rights = torch.cat((data.train_set_right, torch.tensor(wrong_right_indices), torch.tensor(picked_right)), 0)

        lefts = lefts.type(torch.int64)
        rights = rights.type(torch.int64)
        return lefts, rights
      else:
        lefts, rights = helper_funcs.create_fake_data(data.train_set_right, data.train_set_left)
        return lefts, rights
    else:
      return data.train_set_left, data.train_set_right

# %% [markdown]
# ### Model Run

# %%
device = 'cpu' 
source_data = data.to(device) 
model = GCNClassic(384).to(device)
myloss = losses_funcs.CosineSimilarityLoss4(model)


optimizer = torch.optim.SGD(model.parameters(), lr=0.1, weight_decay=0.0005, momentum=0.9)

def train():
    model.train()
    optimizer.zero_grad()
    
    #loss = myloss(source_data, matches) # bei 0, 2
    #double_left_tensor, double_right_tensor = create_fake_data(data.train_set_right, data.train_set_left) # bei 3
    #loss = myloss(source_data, matches, double_left_tensor, double_right_tensor) # bei 1
    lefts, rights = losses_funcs.create_anti_alignment_v41(epoch, matches, source_data)
    loss = myloss(source_data, lefts, rights)
    loss.backward()
    optimizer.step()
    return float(loss)

# %%
precisions = []
recalls = []
losses = []

precision_tests = []
recall_tests = []

wrong_sets_left_train = []
wrong_sets_right_train = []
matches = []
all_matches = []

for epoch in range(1, 1000):
    loss = train()
    prec, rec, matches = helper_funcs.test_harder('train', model, source_data)
    prec_test, rec_test, matches_test= helper_funcs.test_harder('test', model, source_data)
    print(f'TRAINING Epoch: {epoch:02d}, Loss: {loss:.4f}, Precision: {prec:.4f} , Recall: {rec:.4f} ')
    print(f'TEST Epoch: {epoch:02d}, Precision: {prec_test:.4f} , Recall: {rec_test:.4f} ')


    precisions.append(prec)
    recalls.append(rec)
    losses.append(loss)
    precision_tests.append(prec_test)
    recall_tests.append(rec_test)
    x, y, wrong_sets_left, wrong_sets_right = helper_funcs.filter_out_wrong_matches(matches, data)
    wrong_sets_left_train.append(wrong_sets_left)
    wrong_sets_right_train.append(wrong_sets_right)
    all_matches.append(matches)
# Out:
# TRAINING Epoch: 01, Loss: 0.3607, Precision: 0.0000 , Recall: 0.0000
# TEST Epoch: 01, Precision: 0.0000 , Recall: 0.0000
# TRAINING Epoch: 02, Loss: 0.3511, Precision: 0.0000 , Recall: 0.0000
# TEST Epoch: 02, Precision: 0.0000 , Recall: 0.0000
# TRAINING Epoch: 03, Loss: 0.3365, Precision: 0.0000 , Recall: 0.0000
# TEST Epoch: 03, Precision: 0.0000 , Recall: 0.0000
# TRAINING Epoch: 04, Loss: 0.3152, Precision: 0.0000 , Recall: 0.0000
# TEST Epoch: 04, Precision: 0.0000 , Recall: 0.0000
# TRAINING Epoch: 05, Loss: 0.2999, Precision: 0.0000 , Recall: 0.0000
# TEST Epoch: 05, Precision: 0.0000 , Recall: 0.0000
# TRAINING Epoch: 06, Loss: 0.2860, Precision: 0.0000 , Recall: 0.0000
# TEST Epoch: 06, Precision: 0.0000 , Recall: 0.0000
# TRAINING Epoch: 07, Loss: 0.2748, Precision: 0.0000 , Recall: 0.0000
# TEST Epoch: 07, Precision: 0.0000 , Recall: 0.0000
# TRAINING Epoch: 08, Loss: 0.2708, Precision: 0.0000 , Recall: 0.0000
# TEST Epoch: 08, Precision: 0.0000 , Recall: 0.0000
# TRAINING Epoch: 09, Loss: 0.2647, Precision: 0.0000 , Recall: 0.0000
# TEST Epoch: 09, Precision: 0.0000 , Recall: 0.0000
# TRAINING Epoch: 10, Loss: 0.2647, Precision: 0.0000 , Recall: 0.0000
# TEST Epoch: 10, Precision: 0.0000 , Recall: 0.0000
# TRAINING Epoch: 11, Loss: 0.2643, Precision: 0.0000 , Recall: 0.0000
# TEST Epoch: 11, Precision: 0.0000 , Recall: 0.0000
# TRAINING Epoch: 12, Loss: 0.2605, Precision: 0.0000 , Recall: 0.0000
# TEST Epoch: 12, Precision: 0.0000 , Recall: 0.0000
# TRAINING Epoch: 13, Loss: 0.2625, Precision: 0.0000 , Recall: 0.0000
# TEST Epoch: 13, Precision: 0.0000 , Recall: 0.0000
# TRAINING Epoch: 14, Loss: 0.2595, Precision: 0.0000 , Recall: 0.0000
# TEST Epoch: 14, Precision: 0.0000 , Recall: 0.0000
# TRAINING Epoch: 15, Loss: 0.2577, Precision: 0.0000 , Recall: 0.0000
# TEST Epoch: 15, Precision: 0.0000 , Recall: 0.0000
# TRAINING Epoch: 16, Loss: 0.2604, Precision: 0.0000 , Recall: 0.0000
# TEST Epoch: 16, Precision: 0.0000 , Recall: 0.0000
# TRAINING Epoch: 17, Loss: 0.2583, Precision: 0.0000 , Recall: 0.0000
# TEST Epoch: 17, Precision: 0.0000 , Recall: 0.0000
# TRAINING Epoch: 18, Loss: 0.2597, Precision: 0.0000 , Recall: 0.0000
# TEST Epoch: 18, Precision: 0.0000 , Recall: 0.0000
# TRAINING Epoch: 19, Loss: 0.2576, Precision: 0.0000 , Recall: 0.0000
# TEST Epoch: 19, Precision: 0.0000 , Recall: 0.0000
# TRAINING Epoch: 20, Loss: 0.2563, Precision: 0.0000 , Recall: 0.0000
# TEST Epoch: 20, Precision: 0.0000 , Recall: 0.0000
# TRAINING Epoch: 21, Loss: 0.2588, Precision: 0.0000 , Recall: 0.0000
# TEST Epoch: 21, Precision: 0.0000 , Recall: 0.0000
# TRAINING Epoch: 22, Loss: 0.2578, Precision: 0.0005 , Recall: 0.0009
# TEST Epoch: 22, Precision: 0.0000 , Recall: 0.0000
# TRAINING Epoch: 23, Loss: 0.2587, Precision: 0.0005 , Recall: 0.0009
# TEST Epoch: 23, Precision: 0.0000 , Recall: 0.0000
# TRAINING Epoch: 24, Loss: 0.2535, Precision: 0.0005 , Recall: 0.0009
# TEST Epoch: 24, Precision: 0.0000 , Recall: 0.0000
# TRAINING Epoch: 25, Loss: 0.2547, Precision: 0.0005 , Recall: 0.0009
# TEST Epoch: 25, Precision: 0.0000 , Recall: 0.0000
# TRAINING Epoch: 26, Loss: 0.2580, Precision: 0.0005 , Recall: 0.0009
# TEST Epoch: 26, Precision: 0.0000 , Recall: 0.0000
# TRAINING Epoch: 27, Loss: 0.2538, Precision: 0.0005 , Recall: 0.0009
# TEST Epoch: 27, Precision: 0.0000 , Recall: 0.0000
# TRAINING Epoch: 28, Loss: 0.2576, Precision: 0.0005 , Recall: 0.0009
# TEST Epoch: 28, Precision: 0.0000 , Recall: 0.0000
# TRAINING Epoch: 29, Loss: 0.2542, Precision: 0.0005 , Recall: 0.0009
# TEST Epoch: 29, Precision: 0.0000 , Recall: 0.0000
# TRAINING Epoch: 30, Loss: 0.2565, Precision: 0.0005 , Recall: 0.0009
# TEST Epoch: 30, Precision: 0.0000 , Recall: 0.0000
# TRAINING Epoch: 31, Loss: 0.2547, Precision: 0.0005 , Recall: 0.0009
# TEST Epoch: 31, Precision: 0.0015 , Recall: 0.0033
# TRAINING Epoch: 32, Loss: 0.2542, Precision: 0.0005 , Recall: 0.0009
# TEST Epoch: 32, Precision: 0.0015 , Recall: 0.0033
# TRAINING Epoch: 33, Loss: 0.2542, Precision: 0.0005 , Recall: 0.0009
# TEST Epoch: 33, Precision: 0.0015 , Recall: 0.0033
# TRAINING Epoch: 34, Loss: 0.2551, Precision: 0.0009 , Recall: 0.0019
# TEST Epoch: 34, Precision: 0.0015 , Recall: 0.0033
# TRAINING Epoch: 35, Loss: 0.2543, Precision: 0.0009 , Recall: 0.0019
# TEST Epoch: 35, Precision: 0.0015 , Recall: 0.0033
# TRAINING Epoch: 36, Loss: 0.2527, Precision: 0.0009 , Recall: 0.0019
# TEST Epoch: 36, Precision: 0.0014 , Recall: 0.0033
# TRAINING Epoch: 37, Loss: 0.2510, Precision: 0.0005 , Recall: 0.0009
# TEST Epoch: 37, Precision: 0.0014 , Recall: 0.0033
# TRAINING Epoch: 38, Loss: 0.2539, Precision: 0.0005 , Recall: 0.0009
# TEST Epoch: 38, Precision: 0.0014 , Recall: 0.0033
# TRAINING Epoch: 39, Loss: 0.2510, Precision: 0.0005 , Recall: 0.0009
# TEST Epoch: 39, Precision: 0.0014 , Recall: 0.0033
# TRAINING Epoch: 40, Loss: 0.2531, Precision: 0.0005 , Recall: 0.0009
# TEST Epoch: 40, Precision: 0.0014 , Recall: 0.0033
# TRAINING Epoch: 41, Loss: 0.2523, Precision: 0.0005 , Recall: 0.0009
# TEST Epoch: 41, Precision: 0.0014 , Recall: 0.0033
# TRAINING Epoch: 42, Loss: 0.2520, Precision: 0.0005 , Recall: 0.0009
# TEST Epoch: 42, Precision: 0.0013 , Recall: 0.0033
# TRAINING Epoch: 43, Loss: 0.2531, Precision: 0.0000 , Recall: 0.0000
# TEST Epoch: 43, Precision: 0.0013 , Recall: 0.0033
# TRAINING Epoch: 44, Loss: 0.2511, Precision: 0.0000 , Recall: 0.0000
# TEST Epoch: 44, Precision: 0.0013 , Recall: 0.0033
# TRAINING Epoch: 45, Loss: 0.2546, Precision: 0.0000 , Recall: 0.0000
# TEST Epoch: 45, Precision: 0.0027 , Recall: 0.0066
# TRAINING Epoch: 46, Loss: 0.2529, Precision: 0.0000 , Recall: 0.0000
# TEST Epoch: 46, Precision: 0.0027 , Recall: 0.0066
# TRAINING Epoch: 47, Loss: 0.2531, Precision: 0.0000 , Recall: 0.0000
# TEST Epoch: 47, Precision: 0.0027 , Recall: 0.0066
# TRAINING Epoch: 48, Loss: 0.2538, Precision: 0.0000 , Recall: 0.0000
# TEST Epoch: 48, Precision: 0.0026 , Recall: 0.0066
# TRAINING Epoch: 49, Loss: 0.2543, Precision: 0.0000 , Recall: 0.0000
# TEST Epoch: 49, Precision: 0.0026 , Recall: 0.0066
# TRAINING Epoch: 50, Loss: 0.2503, Precision: 0.0004 , Recall: 0.0009
# TEST Epoch: 50, Precision: 0.0026 , Recall: 0.0066
# TRAINING Epoch: 51, Loss: 0.2540, Precision: 0.0004 , Recall: 0.0009
# TEST Epoch: 51, Precision: 0.0026 , Recall: 0.0066
# TRAINING Epoch: 52, Loss: 0.2541, Precision: 0.0004 , Recall: 0.0009
# TEST Epoch: 52, Precision: 0.0026 , Recall: 0.0066
# TRAINING Epoch: 53, Loss: 0.2523, Precision: 0.0004 , Recall: 0.0009
# TEST Epoch: 53, Precision: 0.0026 , Recall: 0.0066
# TRAINING Epoch: 54, Loss: 0.2528, Precision: 0.0004 , Recall: 0.0009
# TEST Epoch: 54, Precision: 0.0026 , Recall: 0.0066
# TRAINING Epoch: 55, Loss: 0.2517, Precision: 0.0004 , Recall: 0.0009
# TEST Epoch: 55, Precision: 0.0026 , Recall: 0.0066
# TRAINING Epoch: 56, Loss: 0.2525, Precision: 0.0004 , Recall: 0.0009
# TEST Epoch: 56, Precision: 0.0026 , Recall: 0.0066
# TRAINING Epoch: 57, Loss: 0.2518, Precision: 0.0004 , Recall: 0.0009
# TEST Epoch: 57, Precision: 0.0026 , Recall: 0.0066
# TRAINING Epoch: 58, Loss: 0.2530, Precision: 0.0004 , Recall: 0.0009
# TEST Epoch: 58, Precision: 0.0026 , Recall: 0.0066
# TRAINING Epoch: 59, Loss: 0.2504, Precision: 0.0004 , Recall: 0.0009
# TEST Epoch: 59, Precision: 0.0027 , Recall: 0.0066
# TRAINING Epoch: 60, Loss: 0.2535, Precision: 0.0004 , Recall: 0.0009
# TEST Epoch: 60, Precision: 0.0027 , Recall: 0.0066
# TRAINING Epoch: 61, Loss: 0.2516, Precision: 0.0004 , Recall: 0.0009
# TEST Epoch: 61, Precision: 0.0027 , Recall: 0.0066
# TRAINING Epoch: 62, Loss: 0.2538, Precision: 0.0004 , Recall: 0.0009
# TEST Epoch: 62, Precision: 0.0027 , Recall: 0.0066
# TRAINING Epoch: 63, Loss: 0.2520, Precision: 0.0004 , Recall: 0.0009
# TEST Epoch: 63, Precision: 0.0027 , Recall: 0.0066
# TRAINING Epoch: 64, Loss: 0.2495, Precision: 0.0008 , Recall: 0.0019
# TEST Epoch: 64, Precision: 0.0027 , Recall: 0.0066
# TRAINING Epoch: 65, Loss: 0.2538, Precision: 0.0008 , Recall: 0.0019
# TEST Epoch: 65, Precision: 0.0027 , Recall: 0.0066
# TRAINING Epoch: 66, Loss: 0.2548, Precision: 0.0008 , Recall: 0.0019
# TEST Epoch: 66, Precision: 0.0027 , Recall: 0.0066
# TRAINING Epoch: 67, Loss: 0.2519, Precision: 0.0008 , Recall: 0.0019
# TEST Epoch: 67, Precision: 0.0027 , Recall: 0.0066
# TRAINING Epoch: 68, Loss: 0.2529, Precision: 0.0008 , Recall: 0.0019
# TEST Epoch: 68, Precision: 0.0026 , Recall: 0.0066
# TRAINING Epoch: 69, Loss: 0.2511, Precision: 0.0008 , Recall: 0.0019
# TEST Epoch: 69, Precision: 0.0026 , Recall: 0.0066
# TRAINING Epoch: 70, Loss: 0.2529, Precision: 0.0008 , Recall: 0.0019
# TEST Epoch: 70, Precision: 0.0026 , Recall: 0.0066
# TRAINING Epoch: 71, Loss: 0.2531, Precision: 0.0008 , Recall: 0.0019
# TEST Epoch: 71, Precision: 0.0026 , Recall: 0.0066
# TRAINING Epoch: 72, Loss: 0.2518, Precision: 0.0008 , Recall: 0.0019
# TEST Epoch: 72, Precision: 0.0026 , Recall: 0.0066
# TRAINING Epoch: 73, Loss: 0.2522, Precision: 0.0013 , Recall: 0.0028
# TEST Epoch: 73, Precision: 0.0026 , Recall: 0.0066
# TRAINING Epoch: 74, Loss: 0.2515, Precision: 0.0013 , Recall: 0.0028
# TEST Epoch: 74, Precision: 0.0026 , Recall: 0.0066
# TRAINING Epoch: 75, Loss: 0.2514, Precision: 0.0013 , Recall: 0.0028
# TEST Epoch: 75, Precision: 0.0026 , Recall: 0.0066
# TRAINING Epoch: 76, Loss: 0.2511, Precision: 0.0013 , Recall: 0.0028
# TEST Epoch: 76, Precision: 0.0026 , Recall: 0.0066
# TRAINING Epoch: 77, Loss: 0.2511, Precision: 0.0013 , Recall: 0.0028
# TEST Epoch: 77, Precision: 0.0026 , Recall: 0.0066
# TRAINING Epoch: 78, Loss: 0.2497, Precision: 0.0013 , Recall: 0.0028
# TEST Epoch: 78, Precision: 0.0026 , Recall: 0.0066
# TRAINING Epoch: 79, Loss: 0.2511, Precision: 0.0013 , Recall: 0.0028
# TEST Epoch: 79, Precision: 0.0026 , Recall: 0.0066
# TRAINING Epoch: 80, Loss: 0.2511, Precision: 0.0013 , Recall: 0.0028
# TEST Epoch: 80, Precision: 0.0026 , Recall: 0.0066
# TRAINING Epoch: 81, Loss: 0.2515, Precision: 0.0013 , Recall: 0.0028
# TEST Epoch: 81, Precision: 0.0025 , Recall: 0.0066
# TRAINING Epoch: 82, Loss: 0.2501, Precision: 0.0013 , Recall: 0.0028
# TEST Epoch: 82, Precision: 0.0025 , Recall: 0.0066
# TRAINING Epoch: 83, Loss: 0.2532, Precision: 0.0013 , Recall: 0.0028
# TEST Epoch: 83, Precision: 0.0025 , Recall: 0.0066
# TRAINING Epoch: 84, Loss: 0.2508, Precision: 0.0013 , Recall: 0.0028
# TEST Epoch: 84, Precision: 0.0025 , Recall: 0.0066
# TRAINING Epoch: 85, Loss: 0.2509, Precision: 0.0013 , Recall: 0.0028
# TEST Epoch: 85, Precision: 0.0025 , Recall: 0.0066
# TRAINING Epoch: 86, Loss: 0.2518, Precision: 0.0013 , Recall: 0.0028
# TEST Epoch: 86, Precision: 0.0025 , Recall: 0.0066
# TRAINING Epoch: 87, Loss: 0.2515, Precision: 0.0013 , Recall: 0.0028
# TEST Epoch: 87, Precision: 0.0025 , Recall: 0.0066
# TRAINING Epoch: 88, Loss: 0.2501, Precision: 0.0013 , Recall: 0.0028
# TEST Epoch: 88, Precision: 0.0025 , Recall: 0.0066
# TRAINING Epoch: 89, Loss: 0.2544, Precision: 0.0013 , Recall: 0.0028
# TEST Epoch: 89, Precision: 0.0025 , Recall: 0.0066
# TRAINING Epoch: 90, Loss: 0.2519, Precision: 0.0013 , Recall: 0.0028
# TEST Epoch: 90, Precision: 0.0025 , Recall: 0.0066
# TRAINING Epoch: 91, Loss: 0.2531, Precision: 0.0013 , Recall: 0.0028
# TEST Epoch: 91, Precision: 0.0025 , Recall: 0.0066
# TRAINING Epoch: 92, Loss: 0.2485, Precision: 0.0013 , Recall: 0.0028
# TEST Epoch: 92, Precision: 0.0025 , Recall: 0.0066
# TRAINING Epoch: 93, Loss: 0.2514, Precision: 0.0013 , Recall: 0.0028
# TEST Epoch: 93, Precision: 0.0025 , Recall: 0.0066
# TRAINING Epoch: 94, Loss: 0.2523, Precision: 0.0013 , Recall: 0.0028
# TEST Epoch: 94, Precision: 0.0012 , Recall: 0.0033
# TRAINING Epoch: 95, Loss: 0.2508, Precision: 0.0013 , Recall: 0.0028
# TEST Epoch: 95, Precision: 0.0012 , Recall: 0.0033
# TRAINING Epoch: 96, Loss: 0.2499, Precision: 0.0008 , Recall: 0.0019
# TEST Epoch: 96, Precision: 0.0012 , Recall: 0.0033
# TRAINING Epoch: 97, Loss: 0.2499, Precision: 0.0008 , Recall: 0.0019
# TEST Epoch: 97, Precision: 0.0012 , Recall: 0.0033
# TRAINING Epoch: 98, Loss: 0.2539, Precision: 0.0008 , Recall: 0.0019
# TEST Epoch: 98, Precision: 0.0012 , Recall: 0.0033
# TRAINING Epoch: 99, Loss: 0.2512, Precision: 0.0008 , Recall: 0.0019
# TEST Epoch: 99, Precision: 0.0012 , Recall: 0.0033
# TRAINING Epoch: 100, Loss: 0.2494, Precision: 0.0009 , Recall: 0.0019
# TEST Epoch: 100, Precision: 0.0012 , Recall: 0.0033
# TRAINING Epoch: 101, Loss: 0.2483, Precision: 0.0009 , Recall: 0.0019
# TEST Epoch: 101, Precision: 0.0012 , Recall: 0.0033
# TRAINING Epoch: 102, Loss: 0.2502, Precision: 0.0009 , Recall: 0.0019
# TEST Epoch: 102, Precision: 0.0012 , Recall: 0.0033
# TRAINING Epoch: 103, Loss: 0.2509, Precision: 0.0009 , Recall: 0.0019
# TEST Epoch: 103, Precision: 0.0012 , Recall: 0.0033
# TRAINING Epoch: 104, Loss: 0.2504, Precision: 0.0009 , Recall: 0.0019
# TEST Epoch: 104, Precision: 0.0013 , Recall: 0.0033
# TRAINING Epoch: 105, Loss: 0.2504, Precision: 0.0009 , Recall: 0.0019
# TEST Epoch: 105, Precision: 0.0013 , Recall: 0.0033
# TRAINING Epoch: 106, Loss: 0.2501, Precision: 0.0009 , Recall: 0.0019
# TEST Epoch: 106, Precision: 0.0013 , Recall: 0.0033
# TRAINING Epoch: 107, Loss: 0.2492, Precision: 0.0009 , Recall: 0.0019
# TEST Epoch: 107, Precision: 0.0013 , Recall: 0.0033
# TRAINING Epoch: 108, Loss: 0.2498, Precision: 0.0009 , Recall: 0.0019
# TEST Epoch: 108, Precision: 0.0013 , Recall: 0.0033
# TRAINING Epoch: 109, Loss: 0.2504, Precision: 0.0009 , Recall: 0.0019
# TEST Epoch: 109, Precision: 0.0013 , Recall: 0.0033
# TRAINING Epoch: 110, Loss: 0.2489, Precision: 0.0009 , Recall: 0.0019
# TEST Epoch: 110, Precision: 0.0013 , Recall: 0.0033
# TRAINING Epoch: 111, Loss: 0.2490, Precision: 0.0009 , Recall: 0.0019
# TEST Epoch: 111, Precision: 0.0013 , Recall: 0.0033
# TRAINING Epoch: 112, Loss: 0.2513, Precision: 0.0009 , Recall: 0.0019
# TEST Epoch: 112, Precision: 0.0013 , Recall: 0.0033
# TRAINING Epoch: 113, Loss: 0.2505, Precision: 0.0009 , Recall: 0.0019
# TEST Epoch: 113, Precision: 0.0013 , Recall: 0.0033
# TRAINING Epoch: 114, Loss: 0.2493, Precision: 0.0009 , Recall: 0.0019
# TEST Epoch: 114, Precision: 0.0013 , Recall: 0.0033
# TRAINING Epoch: 115, Loss: 0.2517, Precision: 0.0009 , Recall: 0.0019
# TEST Epoch: 115, Precision: 0.0013 , Recall: 0.0033
# TRAINING Epoch: 116, Loss: 0.2503, Precision: 0.0009 , Recall: 0.0019
# TEST Epoch: 116, Precision: 0.0012 , Recall: 0.0033
# TRAINING Epoch: 117, Loss: 0.2489, Precision: 0.0009 , Recall: 0.0019
# TEST Epoch: 117, Precision: 0.0012 , Recall: 0.0033
# TRAINING Epoch: 118, Loss: 0.2504, Precision: 0.0009 , Recall: 0.0019
# TEST Epoch: 118, Precision: 0.0012 , Recall: 0.0033
# TRAINING Epoch: 119, Loss: 0.2502, Precision: 0.0009 , Recall: 0.0019
# TEST Epoch: 119, Precision: 0.0025 , Recall: 0.0066
# TRAINING Epoch: 120, Loss: 0.2515, Precision: 0.0013 , Recall: 0.0028
# TEST Epoch: 120, Precision: 0.0025 , Recall: 0.0066
# TRAINING Epoch: 121, Loss: 0.2487, Precision: 0.0013 , Recall: 0.0028
# TEST Epoch: 121, Precision: 0.0025 , Recall: 0.0066
# TRAINING Epoch: 122, Loss: 0.2503, Precision: 0.0013 , Recall: 0.0028
# TEST Epoch: 122, Precision: 0.0025 , Recall: 0.0066
# TRAINING Epoch: 123, Loss: 0.2525, Precision: 0.0013 , Recall: 0.0028
# TEST Epoch: 123, Precision: 0.0025 , Recall: 0.0066
# TRAINING Epoch: 124, Loss: 0.2491, Precision: 0.0013 , Recall: 0.0028
# TEST Epoch: 124, Precision: 0.0025 , Recall: 0.0066
# TRAINING Epoch: 125, Loss: 0.2513, Precision: 0.0017 , Recall: 0.0038
# TEST Epoch: 125, Precision: 0.0025 , Recall: 0.0066
# TRAINING Epoch: 126, Loss: 0.2508, Precision: 0.0022 , Recall: 0.0047
# TEST Epoch: 126, Precision: 0.0025 , Recall: 0.0066
# TRAINING Epoch: 127, Loss: 0.2504, Precision: 0.0022 , Recall: 0.0047
# TEST Epoch: 127, Precision: 0.0025 , Recall: 0.0066
# TRAINING Epoch: 128, Loss: 0.2492, Precision: 0.0022 , Recall: 0.0047
# TEST Epoch: 128, Precision: 0.0025 , Recall: 0.0066
# TRAINING Epoch: 129, Loss: 0.2510, Precision: 0.0022 , Recall: 0.0047
# TEST Epoch: 129, Precision: 0.0025 , Recall: 0.0066
# TRAINING Epoch: 130, Loss: 0.2505, Precision: 0.0022 , Recall: 0.0047
# TEST Epoch: 130, Precision: 0.0037 , Recall: 0.0099
# TRAINING Epoch: 131, Loss: 0.2484, Precision: 0.0022 , Recall: 0.0047
# TEST Epoch: 131, Precision: 0.0037 , Recall: 0.0099
# TRAINING Epoch: 132, Loss: 0.2495, Precision: 0.0022 , Recall: 0.0047
# TEST Epoch: 132, Precision: 0.0037 , Recall: 0.0099
# TRAINING Epoch: 133, Loss: 0.2502, Precision: 0.0022 , Recall: 0.0047
# TEST Epoch: 133, Precision: 0.0037 , Recall: 0.0099
# TRAINING Epoch: 134, Loss: 0.2487, Precision: 0.0022 , Recall: 0.0047
# TEST Epoch: 134, Precision: 0.0037 , Recall: 0.0099
# TRAINING Epoch: 135, Loss: 0.2497, Precision: 0.0022 , Recall: 0.0047
# TEST Epoch: 135, Precision: 0.0037 , Recall: 0.0099
# TRAINING Epoch: 136, Loss: 0.2503, Precision: 0.0022 , Recall: 0.0047
# TEST Epoch: 136, Precision: 0.0037 , Recall: 0.0099
# TRAINING Epoch: 137, Loss: 0.2498, Precision: 0.0026 , Recall: 0.0057
# TEST Epoch: 137, Precision: 0.0037 , Recall: 0.0099
# TRAINING Epoch: 138, Loss: 0.2496, Precision: 0.0026 , Recall: 0.0057
# TEST Epoch: 138, Precision: 0.0037 , Recall: 0.0099
# TRAINING Epoch: 139, Loss: 0.2507, Precision: 0.0026 , Recall: 0.0057
# TEST Epoch: 139, Precision: 0.0037 , Recall: 0.0099
# TRAINING Epoch: 140, Loss: 0.2484, Precision: 0.0026 , Recall: 0.0057
# TEST Epoch: 140, Precision: 0.0037 , Recall: 0.0099
# TRAINING Epoch: 141, Loss: 0.2501, Precision: 0.0026 , Recall: 0.0057
# TEST Epoch: 141, Precision: 0.0037 , Recall: 0.0099
# TRAINING Epoch: 142, Loss: 0.2514, Precision: 0.0026 , Recall: 0.0057
# TEST Epoch: 142, Precision: 0.0037 , Recall: 0.0099
# TRAINING Epoch: 143, Loss: 0.2497, Precision: 0.0026 , Recall: 0.0057
# TEST Epoch: 143, Precision: 0.0037 , Recall: 0.0099
# TRAINING Epoch: 144, Loss: 0.2486, Precision: 0.0026 , Recall: 0.0057
# TEST Epoch: 144, Precision: 0.0037 , Recall: 0.0099
# TRAINING Epoch: 145, Loss: 0.2496, Precision: 0.0026 , Recall: 0.0057
# TEST Epoch: 145, Precision: 0.0037 , Recall: 0.0099
# TRAINING Epoch: 146, Loss: 0.2518, Precision: 0.0026 , Recall: 0.0057
# TEST Epoch: 146, Precision: 0.0036 , Recall: 0.0099
# TRAINING Epoch: 147, Loss: 0.2519, Precision: 0.0026 , Recall: 0.0057
# TEST Epoch: 147, Precision: 0.0036 , Recall: 0.0099
# TRAINING Epoch: 148, Loss: 0.2513, Precision: 0.0026 , Recall: 0.0057
# TEST Epoch: 148, Precision: 0.0036 , Recall: 0.0099
# TRAINING Epoch: 149, Loss: 0.2506, Precision: 0.0026 , Recall: 0.0057
# TEST Epoch: 149, Precision: 0.0036 , Recall: 0.0099
# TRAINING Epoch: 150, Loss: 0.2511, Precision: 0.0026 , Recall: 0.0057
# TEST Epoch: 150, Precision: 0.0036 , Recall: 0.0099
# TRAINING Epoch: 151, Loss: 0.2497, Precision: 0.0026 , Recall: 0.0057
# TEST Epoch: 151, Precision: 0.0036 , Recall: 0.0099
# TRAINING Epoch: 152, Loss: 0.2481, Precision: 0.0026 , Recall: 0.0057
# TEST Epoch: 152, Precision: 0.0036 , Recall: 0.0099
# TRAINING Epoch: 153, Loss: 0.2515, Precision: 0.0026 , Recall: 0.0057
# TEST Epoch: 153, Precision: 0.0036 , Recall: 0.0099
# TRAINING Epoch: 154, Loss: 0.2474, Precision: 0.0026 , Recall: 0.0057
# TEST Epoch: 154, Precision: 0.0036 , Recall: 0.0099
# TRAINING Epoch: 155, Loss: 0.2460, Precision: 0.0026 , Recall: 0.0057
# TEST Epoch: 155, Precision: 0.0035 , Recall: 0.0099
# TRAINING Epoch: 156, Loss: 0.2481, Precision: 0.0026 , Recall: 0.0057
# TEST Epoch: 156, Precision: 0.0036 , Recall: 0.0099
# TRAINING Epoch: 157, Loss: 0.2485, Precision: 0.0026 , Recall: 0.0057
# TEST Epoch: 157, Precision: 0.0035 , Recall: 0.0099
# TRAINING Epoch: 158, Loss: 0.2459, Precision: 0.0026 , Recall: 0.0057
# TEST Epoch: 158, Precision: 0.0035 , Recall: 0.0099
# TRAINING Epoch: 159, Loss: 0.2508, Precision: 0.0026 , Recall: 0.0057
# TEST Epoch: 159, Precision: 0.0035 , Recall: 0.0099
# TRAINING Epoch: 160, Loss: 0.2495, Precision: 0.0031 , Recall: 0.0066
# TEST Epoch: 160, Precision: 0.0035 , Recall: 0.0099
# TRAINING Epoch: 161, Loss: 0.2473, Precision: 0.0035 , Recall: 0.0075
# TEST Epoch: 161, Precision: 0.0036 , Recall: 0.0099
# TRAINING Epoch: 162, Loss: 0.2512, Precision: 0.0035 , Recall: 0.0075
# TEST Epoch: 162, Precision: 0.0035 , Recall: 0.0099
# TRAINING Epoch: 163, Loss: 0.2473, Precision: 0.0039 , Recall: 0.0085
# TEST Epoch: 163, Precision: 0.0035 , Recall: 0.0099
# TRAINING Epoch: 164, Loss: 0.2489, Precision: 0.0039 , Recall: 0.0085
# TEST Epoch: 164, Precision: 0.0035 , Recall: 0.0099
# TRAINING Epoch: 165, Loss: 0.2447, Precision: 0.0044 , Recall: 0.0094
# TEST Epoch: 165, Precision: 0.0036 , Recall: 0.0099
# TRAINING Epoch: 166, Loss: 0.2505, Precision: 0.0048 , Recall: 0.0104
# TEST Epoch: 166, Precision: 0.0036 , Recall: 0.0099
# TRAINING Epoch: 167, Loss: 0.2501, Precision: 0.0048 , Recall: 0.0104
# TEST Epoch: 167, Precision: 0.0036 , Recall: 0.0099
# TRAINING Epoch: 168, Loss: 0.2486, Precision: 0.0048 , Recall: 0.0104
# TEST Epoch: 168, Precision: 0.0036 , Recall: 0.0099
# TRAINING Epoch: 169, Loss: 0.2457, Precision: 0.0048 , Recall: 0.0104
# TEST Epoch: 169, Precision: 0.0036 , Recall: 0.0099
# TRAINING Epoch: 170, Loss: 0.2468, Precision: 0.0048 , Recall: 0.0104
# TEST Epoch: 170, Precision: 0.0036 , Recall: 0.0099
# TRAINING Epoch: 171, Loss: 0.2469, Precision: 0.0044 , Recall: 0.0094
# TEST Epoch: 171, Precision: 0.0036 , Recall: 0.0099
# TRAINING Epoch: 172, Loss: 0.2497, Precision: 0.0039 , Recall: 0.0085
# TEST Epoch: 172, Precision: 0.0036 , Recall: 0.0099
# TRAINING Epoch: 173, Loss: 0.2494, Precision: 0.0039 , Recall: 0.0085
# TEST Epoch: 173, Precision: 0.0036 , Recall: 0.0099
# TRAINING Epoch: 174, Loss: 0.2457, Precision: 0.0048 , Recall: 0.0104
# TEST Epoch: 174, Precision: 0.0036 , Recall: 0.0099
# TRAINING Epoch: 175, Loss: 0.2498, Precision: 0.0048 , Recall: 0.0104
# TEST Epoch: 175, Precision: 0.0037 , Recall: 0.0099
# TRAINING Epoch: 176, Loss: 0.2472, Precision: 0.0048 , Recall: 0.0104
# TEST Epoch: 176, Precision: 0.0037 , Recall: 0.0099
# TRAINING Epoch: 177, Loss: 0.2473, Precision: 0.0048 , Recall: 0.0104
# TEST Epoch: 177, Precision: 0.0037 , Recall: 0.0099
# TRAINING Epoch: 178, Loss: 0.2484, Precision: 0.0048 , Recall: 0.0104
# TEST Epoch: 178, Precision: 0.0037 , Recall: 0.0099
# TRAINING Epoch: 179, Loss: 0.2465, Precision: 0.0048 , Recall: 0.0104
# TEST Epoch: 179, Precision: 0.0037 , Recall: 0.0099
# TRAINING Epoch: 180, Loss: 0.2505, Precision: 0.0048 , Recall: 0.0104
# TEST Epoch: 180, Precision: 0.0037 , Recall: 0.0099
# TRAINING Epoch: 181, Loss: 0.2501, Precision: 0.0044 , Recall: 0.0094
# TEST Epoch: 181, Precision: 0.0036 , Recall: 0.0099
# TRAINING Epoch: 182, Loss: 0.2469, Precision: 0.0043 , Recall: 0.0094
# TEST Epoch: 182, Precision: 0.0036 , Recall: 0.0099
# TRAINING Epoch: 183, Loss: 0.2480, Precision: 0.0044 , Recall: 0.0094
# TEST Epoch: 183, Precision: 0.0036 , Recall: 0.0099
# TRAINING Epoch: 184, Loss: 0.2486, Precision: 0.0044 , Recall: 0.0094
# TEST Epoch: 184, Precision: 0.0036 , Recall: 0.0099
# TRAINING Epoch: 185, Loss: 0.2486, Precision: 0.0044 , Recall: 0.0094
# TEST Epoch: 185, Precision: 0.0036 , Recall: 0.0099
# TRAINING Epoch: 186, Loss: 0.2499, Precision: 0.0048 , Recall: 0.0104
# TEST Epoch: 186, Precision: 0.0036 , Recall: 0.0099
# TRAINING Epoch: 187, Loss: 0.2494, Precision: 0.0048 , Recall: 0.0104
# TEST Epoch: 187, Precision: 0.0035 , Recall: 0.0099
# TRAINING Epoch: 188, Loss: 0.2456, Precision: 0.0044 , Recall: 0.0094
# TEST Epoch: 188, Precision: 0.0035 , Recall: 0.0099
# TRAINING Epoch: 189, Loss: 0.2459, Precision: 0.0048 , Recall: 0.0104
# TEST Epoch: 189, Precision: 0.0035 , Recall: 0.0099
# TRAINING Epoch: 190, Loss: 0.2481, Precision: 0.0053 , Recall: 0.0113
# TEST Epoch: 190, Precision: 0.0058 , Recall: 0.0165
# TRAINING Epoch: 191, Loss: 0.2460, Precision: 0.0062 , Recall: 0.0132
# TEST Epoch: 191, Precision: 0.0058 , Recall: 0.0165
# TRAINING Epoch: 192, Loss: 0.2495, Precision: 0.0062 , Recall: 0.0132
# TEST Epoch: 192, Precision: 0.0058 , Recall: 0.0165
# TRAINING Epoch: 193, Loss: 0.2449, Precision: 0.0062 , Recall: 0.0132
# TEST Epoch: 193, Precision: 0.0070 , Recall: 0.0198
# TRAINING Epoch: 194, Loss: 0.2477, Precision: 0.0062 , Recall: 0.0132
# TEST Epoch: 194, Precision: 0.0069 , Recall: 0.0198
# TRAINING Epoch: 195, Loss: 0.2484, Precision: 0.0067 , Recall: 0.0141
# TEST Epoch: 195, Precision: 0.0069 , Recall: 0.0198
# TRAINING Epoch: 196, Loss: 0.2479, Precision: 0.0067 , Recall: 0.0141
# TEST Epoch: 196, Precision: 0.0058 , Recall: 0.0165
# TRAINING Epoch: 197, Loss: 0.2474, Precision: 0.0067 , Recall: 0.0141
# TEST Epoch: 197, Precision: 0.0058 , Recall: 0.0165
# TRAINING Epoch: 198, Loss: 0.2484, Precision: 0.0067 , Recall: 0.0141
# TEST Epoch: 198, Precision: 0.0057 , Recall: 0.0165
# TRAINING Epoch: 199, Loss: 0.2457, Precision: 0.0067 , Recall: 0.0141
# TEST Epoch: 199, Precision: 0.0058 , Recall: 0.0165
# TRAINING Epoch: 200, Loss: 0.2473, Precision: 0.0067 , Recall: 0.0141
# TEST Epoch: 200, Precision: 0.0058 , Recall: 0.0165
# TRAINING Epoch: 201, Loss: 0.2479, Precision: 0.0072 , Recall: 0.0151
# TEST Epoch: 201, Precision: 0.0058 , Recall: 0.0165
# TRAINING Epoch: 202, Loss: 0.2477, Precision: 0.0076 , Recall: 0.0160
# TEST Epoch: 202, Precision: 0.0058 , Recall: 0.0165
# TRAINING Epoch: 203, Loss: 0.2494, Precision: 0.0076 , Recall: 0.0160
# TEST Epoch: 203, Precision: 0.0058 , Recall: 0.0165
# TRAINING Epoch: 204, Loss: 0.2461, Precision: 0.0076 , Recall: 0.0160
# TEST Epoch: 204, Precision: 0.0058 , Recall: 0.0165
# TRAINING Epoch: 205, Loss: 0.2476, Precision: 0.0080 , Recall: 0.0170
# TEST Epoch: 205, Precision: 0.0058 , Recall: 0.0165
# TRAINING Epoch: 206, Loss: 0.2461, Precision: 0.0080 , Recall: 0.0170
# TEST Epoch: 206, Precision: 0.0058 , Recall: 0.0165
# TRAINING Epoch: 207, Loss: 0.2455, Precision: 0.0076 , Recall: 0.0160
# TEST Epoch: 207, Precision: 0.0070 , Recall: 0.0198
# TRAINING Epoch: 208, Loss: 0.2472, Precision: 0.0071 , Recall: 0.0151
# TEST Epoch: 208, Precision: 0.0070 , Recall: 0.0198
# TRAINING Epoch: 209, Loss: 0.2468, Precision: 0.0076 , Recall: 0.0160
# TEST Epoch: 209, Precision: 0.0070 , Recall: 0.0198
# TRAINING Epoch: 210, Loss: 0.2454, Precision: 0.0076 , Recall: 0.0160
# TEST Epoch: 210, Precision: 0.0070 , Recall: 0.0198
# TRAINING Epoch: 211, Loss: 0.2466, Precision: 0.0080 , Recall: 0.0170
# TEST Epoch: 211, Precision: 0.0070 , Recall: 0.0198
# TRAINING Epoch: 212, Loss: 0.2470, Precision: 0.0076 , Recall: 0.0160
# TEST Epoch: 212, Precision: 0.0058 , Recall: 0.0165
# TRAINING Epoch: 213, Loss: 0.2480, Precision: 0.0081 , Recall: 0.0170
# TEST Epoch: 213, Precision: 0.0058 , Recall: 0.0165
# TRAINING Epoch: 214, Loss: 0.2439, Precision: 0.0081 , Recall: 0.0170
# TEST Epoch: 214, Precision: 0.0058 , Recall: 0.0165
# TRAINING Epoch: 215, Loss: 0.2461, Precision: 0.0085 , Recall: 0.0179
# TEST Epoch: 215, Precision: 0.0058 , Recall: 0.0165
# TRAINING Epoch: 216, Loss: 0.2465, Precision: 0.0089 , Recall: 0.0189
# TEST Epoch: 216, Precision: 0.0058 , Recall: 0.0165
# TRAINING Epoch: 217, Loss: 0.2453, Precision: 0.0098 , Recall: 0.0207
# TEST Epoch: 217, Precision: 0.0059 , Recall: 0.0165
# TRAINING Epoch: 218, Loss: 0.2477, Precision: 0.0094 , Recall: 0.0198
# TEST Epoch: 218, Precision: 0.0059 , Recall: 0.0165
# TRAINING Epoch: 219, Loss: 0.2452, Precision: 0.0089 , Recall: 0.0189
# TEST Epoch: 219, Precision: 0.0059 , Recall: 0.0165
# TRAINING Epoch: 220, Loss: 0.2475, Precision: 0.0094 , Recall: 0.0198
# TEST Epoch: 220, Precision: 0.0059 , Recall: 0.0165
# TRAINING Epoch: 221, Loss: 0.2453, Precision: 0.0089 , Recall: 0.0189
# TEST Epoch: 221, Precision: 0.0059 , Recall: 0.0165
# TRAINING Epoch: 222, Loss: 0.2461, Precision: 0.0089 , Recall: 0.0189
# TEST Epoch: 222, Precision: 0.0059 , Recall: 0.0165
# TRAINING Epoch: 223, Loss: 0.2470, Precision: 0.0089 , Recall: 0.0189
# TEST Epoch: 223, Precision: 0.0059 , Recall: 0.0165
# TRAINING Epoch: 224, Loss: 0.2454, Precision: 0.0098 , Recall: 0.0207
# TEST Epoch: 224, Precision: 0.0059 , Recall: 0.0165
# TRAINING Epoch: 225, Loss: 0.2476, Precision: 0.0098 , Recall: 0.0207
# TEST Epoch: 225, Precision: 0.0060 , Recall: 0.0165
# TRAINING Epoch: 226, Loss: 0.2437, Precision: 0.0107 , Recall: 0.0226
# TEST Epoch: 226, Precision: 0.0060 , Recall: 0.0165
# TRAINING Epoch: 227, Loss: 0.2431, Precision: 0.0107 , Recall: 0.0226
# TEST Epoch: 227, Precision: 0.0060 , Recall: 0.0165
# TRAINING Epoch: 228, Loss: 0.2458, Precision: 0.0115 , Recall: 0.0245
# TEST Epoch: 228, Precision: 0.0059 , Recall: 0.0165
# TRAINING Epoch: 229, Loss: 0.2431, Precision: 0.0124 , Recall: 0.0264
# TEST Epoch: 229, Precision: 0.0060 , Recall: 0.0165
# TRAINING Epoch: 230, Loss: 0.2449, Precision: 0.0129 , Recall: 0.0273
# TEST Epoch: 230, Precision: 0.0060 , Recall: 0.0165
# TRAINING Epoch: 231, Loss: 0.2429, Precision: 0.0129 , Recall: 0.0273
# TEST Epoch: 231, Precision: 0.0047 , Recall: 0.0132
# TRAINING Epoch: 232, Loss: 0.2441, Precision: 0.0129 , Recall: 0.0273
# TEST Epoch: 232, Precision: 0.0059 , Recall: 0.0165
# TRAINING Epoch: 233, Loss: 0.2449, Precision: 0.0125 , Recall: 0.0264
# TEST Epoch: 233, Precision: 0.0059 , Recall: 0.0165
# TRAINING Epoch: 234, Loss: 0.2461, Precision: 0.0129 , Recall: 0.0273
# TEST Epoch: 234, Precision: 0.0070 , Recall: 0.0198
# TRAINING Epoch: 235, Loss: 0.2456, Precision: 0.0138 , Recall: 0.0292
# TEST Epoch: 235, Precision: 0.0081 , Recall: 0.0231
# TRAINING Epoch: 236, Loss: 0.2455, Precision: 0.0134 , Recall: 0.0283
# TEST Epoch: 236, Precision: 0.0070 , Recall: 0.0198
# TRAINING Epoch: 237, Loss: 0.2435, Precision: 0.0143 , Recall: 0.0302
# TEST Epoch: 237, Precision: 0.0070 , Recall: 0.0198
# TRAINING Epoch: 238, Loss: 0.2455, Precision: 0.0143 , Recall: 0.0302
# TEST Epoch: 238, Precision: 0.0070 , Recall: 0.0198
# TRAINING Epoch: 239, Loss: 0.2448, Precision: 0.0147 , Recall: 0.0311
# TEST Epoch: 239, Precision: 0.0070 , Recall: 0.0198
# TRAINING Epoch: 240, Loss: 0.2454, Precision: 0.0156 , Recall: 0.0330
# TEST Epoch: 240, Precision: 0.0071 , Recall: 0.0198
# TRAINING Epoch: 241, Loss: 0.2424, Precision: 0.0156 , Recall: 0.0330
# TEST Epoch: 241, Precision: 0.0071 , Recall: 0.0198
# TRAINING Epoch: 242, Loss: 0.2436, Precision: 0.0156 , Recall: 0.0330
# TEST Epoch: 242, Precision: 0.0070 , Recall: 0.0198
# TRAINING Epoch: 243, Loss: 0.2440, Precision: 0.0160 , Recall: 0.0339
# TEST Epoch: 243, Precision: 0.0071 , Recall: 0.0198
# TRAINING Epoch: 244, Loss: 0.2457, Precision: 0.0164 , Recall: 0.0349
# TEST Epoch: 244, Precision: 0.0071 , Recall: 0.0198
# TRAINING Epoch: 245, Loss: 0.2450, Precision: 0.0169 , Recall: 0.0358
# TEST Epoch: 245, Precision: 0.0071 , Recall: 0.0198
# TRAINING Epoch: 246, Loss: 0.2450, Precision: 0.0160 , Recall: 0.0339
# TEST Epoch: 246, Precision: 0.0083 , Recall: 0.0231
# TRAINING Epoch: 247, Loss: 0.2410, Precision: 0.0160 , Recall: 0.0339
# TEST Epoch: 247, Precision: 0.0083 , Recall: 0.0231
# TRAINING Epoch: 248, Loss: 0.2459, Precision: 0.0164 , Recall: 0.0349
# TEST Epoch: 248, Precision: 0.0084 , Recall: 0.0231
# TRAINING Epoch: 249, Loss: 0.2424, Precision: 0.0164 , Recall: 0.0349
# TEST Epoch: 249, Precision: 0.0084 , Recall: 0.0231
# TRAINING Epoch: 250, Loss: 0.2430, Precision: 0.0173 , Recall: 0.0368
# TEST Epoch: 250, Precision: 0.0085 , Recall: 0.0231
# TRAINING Epoch: 251, Loss: 0.2445, Precision: 0.0176 , Recall: 0.0377
# TEST Epoch: 251, Precision: 0.0097 , Recall: 0.0264
# TRAINING Epoch: 252, Loss: 0.2453, Precision: 0.0189 , Recall: 0.0405
# TEST Epoch: 252, Precision: 0.0098 , Recall: 0.0264
# TRAINING Epoch: 253, Loss: 0.2450, Precision: 0.0194 , Recall: 0.0415
# TEST Epoch: 253, Precision: 0.0098 , Recall: 0.0264
# TRAINING Epoch: 254, Loss: 0.2425, Precision: 0.0202 , Recall: 0.0434
# TEST Epoch: 254, Precision: 0.0098 , Recall: 0.0264
# TRAINING Epoch: 255, Loss: 0.2422, Precision: 0.0216 , Recall: 0.0462
# TEST Epoch: 255, Precision: 0.0110 , Recall: 0.0297
# TRAINING Epoch: 256, Loss: 0.2438, Precision: 0.0226 , Recall: 0.0481
# TEST Epoch: 256, Precision: 0.0122 , Recall: 0.0330
# TRAINING Epoch: 257, Loss: 0.2436, Precision: 0.0226 , Recall: 0.0481
# TEST Epoch: 257, Precision: 0.0133 , Recall: 0.0363
# TRAINING Epoch: 258, Loss: 0.2442, Precision: 0.0239 , Recall: 0.0509
# TEST Epoch: 258, Precision: 0.0133 , Recall: 0.0363
# TRAINING Epoch: 259, Loss: 0.2443, Precision: 0.0247 , Recall: 0.0528
# TEST Epoch: 259, Precision: 0.0144 , Recall: 0.0396
# TRAINING Epoch: 260, Loss: 0.2442, Precision: 0.0257 , Recall: 0.0547
# TEST Epoch: 260, Precision: 0.0156 , Recall: 0.0429
# TRAINING Epoch: 261, Loss: 0.2417, Precision: 0.0256 , Recall: 0.0547
# TEST Epoch: 261, Precision: 0.0155 , Recall: 0.0429
# TRAINING Epoch: 262, Loss: 0.2431, Precision: 0.0257 , Recall: 0.0547
# TEST Epoch: 262, Precision: 0.0156 , Recall: 0.0429
# TRAINING Epoch: 263, Loss: 0.2405, Precision: 0.0263 , Recall: 0.0556
# TEST Epoch: 263, Precision: 0.0156 , Recall: 0.0429
# TRAINING Epoch: 264, Loss: 0.2448, Precision: 0.0264 , Recall: 0.0556
# TEST Epoch: 264, Precision: 0.0156 , Recall: 0.0429
# TRAINING Epoch: 265, Loss: 0.2430, Precision: 0.0272 , Recall: 0.0575
# TEST Epoch: 265, Precision: 0.0156 , Recall: 0.0429
# TRAINING Epoch: 266, Loss: 0.2419, Precision: 0.0291 , Recall: 0.0613
# TEST Epoch: 266, Precision: 0.0157 , Recall: 0.0429
# TRAINING Epoch: 267, Loss: 0.2441, Precision: 0.0286 , Recall: 0.0603
# TEST Epoch: 267, Precision: 0.0157 , Recall: 0.0429
# TRAINING Epoch: 268, Loss: 0.2428, Precision: 0.0287 , Recall: 0.0603
# TEST Epoch: 268, Precision: 0.0158 , Recall: 0.0429
# TRAINING Epoch: 269, Loss: 0.2422, Precision: 0.0301 , Recall: 0.0631
# TEST Epoch: 269, Precision: 0.0157 , Recall: 0.0429
# TRAINING Epoch: 270, Loss: 0.2417, Precision: 0.0316 , Recall: 0.0660
# TEST Epoch: 270, Precision: 0.0170 , Recall: 0.0462
# TRAINING Epoch: 271, Loss: 0.2431, Precision: 0.0312 , Recall: 0.0650
# TEST Epoch: 271, Precision: 0.0184 , Recall: 0.0495
# TRAINING Epoch: 272, Loss: 0.2418, Precision: 0.0314 , Recall: 0.0650
# TEST Epoch: 272, Precision: 0.0197 , Recall: 0.0528
# TRAINING Epoch: 273, Loss: 0.2406, Precision: 0.0323 , Recall: 0.0669
# TEST Epoch: 273, Precision: 0.0184 , Recall: 0.0495
# TRAINING Epoch: 274, Loss: 0.2414, Precision: 0.0321 , Recall: 0.0660
# TEST Epoch: 274, Precision: 0.0186 , Recall: 0.0495
# TRAINING Epoch: 275, Loss: 0.2424, Precision: 0.0318 , Recall: 0.0650
# TEST Epoch: 275, Precision: 0.0186 , Recall: 0.0495
# TRAINING Epoch: 276, Loss: 0.2433, Precision: 0.0322 , Recall: 0.0660
# TEST Epoch: 276, Precision: 0.0185 , Recall: 0.0495
# TRAINING Epoch: 277, Loss: 0.2441, Precision: 0.0318 , Recall: 0.0650
# TEST Epoch: 277, Precision: 0.0186 , Recall: 0.0495
# TRAINING Epoch: 278, Loss: 0.2430, Precision: 0.0332 , Recall: 0.0679
# TEST Epoch: 278, Precision: 0.0186 , Recall: 0.0495
# TRAINING Epoch: 279, Loss: 0.2393, Precision: 0.0342 , Recall: 0.0697
# TEST Epoch: 279, Precision: 0.0188 , Recall: 0.0495
# TRAINING Epoch: 280, Loss: 0.2418, Precision: 0.0348 , Recall: 0.0707
# TEST Epoch: 280, Precision: 0.0188 , Recall: 0.0495
# TRAINING Epoch: 281, Loss: 0.2409, Precision: 0.0350 , Recall: 0.0707
# TEST Epoch: 281, Precision: 0.0189 , Recall: 0.0495
# TRAINING Epoch: 282, Loss: 0.2419, Precision: 0.0347 , Recall: 0.0697
# TEST Epoch: 282, Precision: 0.0190 , Recall: 0.0495
# TRAINING Epoch: 283, Loss: 0.2409, Precision: 0.0360 , Recall: 0.0716
# TEST Epoch: 283, Precision: 0.0192 , Recall: 0.0495
# TRAINING Epoch: 284, Loss: 0.2407, Precision: 0.0366 , Recall: 0.0726
# TEST Epoch: 284, Precision: 0.0193 , Recall: 0.0495
# TRAINING Epoch: 285, Loss: 0.2418, Precision: 0.0372 , Recall: 0.0735
# TEST Epoch: 285, Precision: 0.0180 , Recall: 0.0462
# TRAINING Epoch: 286, Loss: 0.2407, Precision: 0.0390 , Recall: 0.0763
# TEST Epoch: 286, Precision: 0.0181 , Recall: 0.0462
# TRAINING Epoch: 287, Loss: 0.2451, Precision: 0.0381 , Recall: 0.0745
# TEST Epoch: 287, Precision: 0.0183 , Recall: 0.0462
# TRAINING Epoch: 288, Loss: 0.2413, Precision: 0.0387 , Recall: 0.0754
# TEST Epoch: 288, Precision: 0.0197 , Recall: 0.0495
# TRAINING Epoch: 289, Loss: 0.2406, Precision: 0.0389 , Recall: 0.0754
# TEST Epoch: 289, Precision: 0.0198 , Recall: 0.0495
# TRAINING Epoch: 290, Loss: 0.2392, Precision: 0.0390 , Recall: 0.0754
# TEST Epoch: 290, Precision: 0.0201 , Recall: 0.0495
# TRAINING Epoch: 291, Loss: 0.2401, Precision: 0.0401 , Recall: 0.0773
# TEST Epoch: 291, Precision: 0.0201 , Recall: 0.0495
# TRAINING Epoch: 292, Loss: 0.2397, Precision: 0.0403 , Recall: 0.0773
# TEST Epoch: 292, Precision: 0.0202 , Recall: 0.0495
# TRAINING Epoch: 293, Loss: 0.2385, Precision: 0.0409 , Recall: 0.0782
# TEST Epoch: 293, Precision: 0.0202 , Recall: 0.0495
# TRAINING Epoch: 294, Loss: 0.2432, Precision: 0.0436 , Recall: 0.0829
# TEST Epoch: 294, Precision: 0.0216 , Recall: 0.0528
# TRAINING Epoch: 295, Loss: 0.2403, Precision: 0.0438 , Recall: 0.0829
# TEST Epoch: 295, Precision: 0.0229 , Recall: 0.0561
# TRAINING Epoch: 296, Loss: 0.2379, Precision: 0.0442 , Recall: 0.0829
# TEST Epoch: 296, Precision: 0.0240 , Recall: 0.0594
# TRAINING Epoch: 297, Loss: 0.2401, Precision: 0.0445 , Recall: 0.0829
# TEST Epoch: 297, Precision: 0.0254 , Recall: 0.0627
# TRAINING Epoch: 298, Loss: 0.2373, Precision: 0.0460 , Recall: 0.0848
# TEST Epoch: 298, Precision: 0.0266 , Recall: 0.0660
# TRAINING Epoch: 299, Loss: 0.2387, Precision: 0.0476 , Recall: 0.0877
# TEST Epoch: 299, Precision: 0.0267 , Recall: 0.0660
# TRAINING Epoch: 300, Loss: 0.2414, Precision: 0.0480 , Recall: 0.0877
# TEST Epoch: 300, Precision: 0.0265 , Recall: 0.0660
# TRAINING Epoch: 301, Loss: 0.2388, Precision: 0.0514 , Recall: 0.0933
# TEST Epoch: 301, Precision: 0.0278 , Recall: 0.0693
# TRAINING Epoch: 302, Loss: 0.2386, Precision: 0.0519 , Recall: 0.0933
# TEST Epoch: 302, Precision: 0.0280 , Recall: 0.0693
# TRAINING Epoch: 303, Loss: 0.2415, Precision: 0.0536 , Recall: 0.0952
# TEST Epoch: 303, Precision: 0.0296 , Recall: 0.0726
# TRAINING Epoch: 304, Loss: 0.2405, Precision: 0.0529 , Recall: 0.0933
# TEST Epoch: 304, Precision: 0.0286 , Recall: 0.0693
# TRAINING Epoch: 305, Loss: 0.2394, Precision: 0.0559 , Recall: 0.0980
# TEST Epoch: 305, Precision: 0.0316 , Recall: 0.0759
# TRAINING Epoch: 306, Loss: 0.2388, Precision: 0.0566 , Recall: 0.0990
# TEST Epoch: 306, Precision: 0.0319 , Recall: 0.0759
# TRAINING Epoch: 307, Loss: 0.2375, Precision: 0.0604 , Recall: 0.1046
# TEST Epoch: 307, Precision: 0.0325 , Recall: 0.0759
# TRAINING Epoch: 308, Loss: 0.2383, Precision: 0.0617 , Recall: 0.1056
# TEST Epoch: 308, Precision: 0.0329 , Recall: 0.0759
# TRAINING Epoch: 309, Loss: 0.2384, Precision: 0.0646 , Recall: 0.1093
# TEST Epoch: 309, Precision: 0.0335 , Recall: 0.0759
# TRAINING Epoch: 310, Loss: 0.2421, Precision: 0.0647 , Recall: 0.1093
# TEST Epoch: 310, Precision: 0.0337 , Recall: 0.0759
# TRAINING Epoch: 311, Loss: 0.2396, Precision: 0.0670 , Recall: 0.1122
# TEST Epoch: 311, Precision: 0.0354 , Recall: 0.0792
# TRAINING Epoch: 312, Loss: 0.2369, Precision: 0.0701 , Recall: 0.1159
# TEST Epoch: 312, Precision: 0.0371 , Recall: 0.0825
# TRAINING Epoch: 313, Loss: 0.2407, Precision: 0.0713 , Recall: 0.1169
# TEST Epoch: 313, Precision: 0.0359 , Recall: 0.0792
# TRAINING Epoch: 314, Loss: 0.2360, Precision: 0.0711 , Recall: 0.1159
# TEST Epoch: 314, Precision: 0.0359 , Recall: 0.0792
# TRAINING Epoch: 315, Loss: 0.2379, Precision: 0.0737 , Recall: 0.1197
# TEST Epoch: 315, Precision: 0.0379 , Recall: 0.0825
# TRAINING Epoch: 316, Loss: 0.2366, Precision: 0.0757 , Recall: 0.1225
# TEST Epoch: 316, Precision: 0.0393 , Recall: 0.0858
# TRAINING Epoch: 317, Loss: 0.2408, Precision: 0.0776 , Recall: 0.1244
# TEST Epoch: 317, Precision: 0.0413 , Recall: 0.0891
# TRAINING Epoch: 318, Loss: 0.2395, Precision: 0.0821 , Recall: 0.1301
# TEST Epoch: 318, Precision: 0.0419 , Recall: 0.0891
# TRAINING Epoch: 319, Loss: 0.2421, Precision: 0.0843 , Recall: 0.1320
# TEST Epoch: 319, Precision: 0.0437 , Recall: 0.0924
# TRAINING Epoch: 320, Loss: 0.2389, Precision: 0.0855 , Recall: 0.1329
# TEST Epoch: 320, Precision: 0.0429 , Recall: 0.0891
# TRAINING Epoch: 321, Loss: 0.2389, Precision: 0.0850 , Recall: 0.1310
# TEST Epoch: 321, Precision: 0.0435 , Recall: 0.0891
# TRAINING Epoch: 322, Loss: 0.2360, Precision: 0.0876 , Recall: 0.1348
# TEST Epoch: 322, Precision: 0.0454 , Recall: 0.0924
# TRAINING Epoch: 323, Loss: 0.2401, Precision: 0.0903 , Recall: 0.1385
# TEST Epoch: 323, Precision: 0.0485 , Recall: 0.0990
# TRAINING Epoch: 324, Loss: 0.2391, Precision: 0.0916 , Recall: 0.1395
# TEST Epoch: 324, Precision: 0.0488 , Recall: 0.0990
# TRAINING Epoch: 325, Loss: 0.2398, Precision: 0.0937 , Recall: 0.1423
# TEST Epoch: 325, Precision: 0.0507 , Recall: 0.1023
# TRAINING Epoch: 326, Loss: 0.2385, Precision: 0.0952 , Recall: 0.1433
# TEST Epoch: 326, Precision: 0.0509 , Recall: 0.1023
# TRAINING Epoch: 327, Loss: 0.2392, Precision: 0.0950 , Recall: 0.1423
# TEST Epoch: 327, Precision: 0.0505 , Recall: 0.1023
# TRAINING Epoch: 328, Loss: 0.2357, Precision: 0.0964 , Recall: 0.1433
# TEST Epoch: 328, Precision: 0.0511 , Recall: 0.1023
# TRAINING Epoch: 329, Loss: 0.2384, Precision: 0.0962 , Recall: 0.1414
# TEST Epoch: 329, Precision: 0.0545 , Recall: 0.1089
# TRAINING Epoch: 330, Loss: 0.2369, Precision: 0.0960 , Recall: 0.1404
# TEST Epoch: 330, Precision: 0.0535 , Recall: 0.1056
# TRAINING Epoch: 331, Loss: 0.2376, Precision: 0.0987 , Recall: 0.1433
# TEST Epoch: 331, Precision: 0.0553 , Recall: 0.1089
# TRAINING Epoch: 332, Loss: 0.2376, Precision: 0.1005 , Recall: 0.1451
# TEST Epoch: 332, Precision: 0.0533 , Recall: 0.1056
# TRAINING Epoch: 333, Loss: 0.2394, Precision: 0.1036 , Recall: 0.1480
# TEST Epoch: 333, Precision: 0.0557 , Recall: 0.1089
# TRAINING Epoch: 334, Loss: 0.2378, Precision: 0.1048 , Recall: 0.1489
# TEST Epoch: 334, Precision: 0.0600 , Recall: 0.1155
# TRAINING Epoch: 335, Loss: 0.2394, Precision: 0.1096 , Recall: 0.1546
# TEST Epoch: 335, Precision: 0.0583 , Recall: 0.1122
# TRAINING Epoch: 336, Loss: 0.2359, Precision: 0.1116 , Recall: 0.1565
# TEST Epoch: 336, Precision: 0.0588 , Recall: 0.1122
# TRAINING Epoch: 337, Loss: 0.2403, Precision: 0.1142 , Recall: 0.1602
# TEST Epoch: 337, Precision: 0.0616 , Recall: 0.1155
# TRAINING Epoch: 338, Loss: 0.2361, Precision: 0.1149 , Recall: 0.1612
# TEST Epoch: 338, Precision: 0.0604 , Recall: 0.1122
# TRAINING Epoch: 339, Loss: 0.2363, Precision: 0.1155 , Recall: 0.1612
# TEST Epoch: 339, Precision: 0.0621 , Recall: 0.1155
# TRAINING Epoch: 340, Loss: 0.2397, Precision: 0.1176 , Recall: 0.1631
# TEST Epoch: 340, Precision: 0.0621 , Recall: 0.1155
# TRAINING Epoch: 341, Loss: 0.2347, Precision: 0.1194 , Recall: 0.1649
# TEST Epoch: 341, Precision: 0.0628 , Recall: 0.1155
# TRAINING Epoch: 342, Loss: 0.2391, Precision: 0.1224 , Recall: 0.1678
# TEST Epoch: 342, Precision: 0.0627 , Recall: 0.1155
# TRAINING Epoch: 343, Loss: 0.2401, Precision: 0.1232 , Recall: 0.1678
# TEST Epoch: 343, Precision: 0.0650 , Recall: 0.1188
# TRAINING Epoch: 344, Loss: 0.2392, Precision: 0.1269 , Recall: 0.1715
# TEST Epoch: 344, Precision: 0.0652 , Recall: 0.1188
# TRAINING Epoch: 345, Loss: 0.2385, Precision: 0.1295 , Recall: 0.1744
# TEST Epoch: 345, Precision: 0.0651 , Recall: 0.1188
# TRAINING Epoch: 346, Loss: 0.2369, Precision: 0.1312 , Recall: 0.1762
# TEST Epoch: 346, Precision: 0.0688 , Recall: 0.1254
# TRAINING Epoch: 347, Loss: 0.2372, Precision: 0.1310 , Recall: 0.1762
# TEST Epoch: 347, Precision: 0.0691 , Recall: 0.1254
# TRAINING Epoch: 348, Loss: 0.2375, Precision: 0.1324 , Recall: 0.1781
# TEST Epoch: 348, Precision: 0.0696 , Recall: 0.1254
# TRAINING Epoch: 349, Loss: 0.2357, Precision: 0.1326 , Recall: 0.1781
# TEST Epoch: 349, Precision: 0.0716 , Recall: 0.1287
# TRAINING Epoch: 350, Loss: 0.2360, Precision: 0.1342 , Recall: 0.1791
# TEST Epoch: 350, Precision: 0.0769 , Recall: 0.1353
# TRAINING Epoch: 351, Loss: 0.2366, Precision: 0.1331 , Recall: 0.1772
# TEST Epoch: 351, Precision: 0.0771 , Recall: 0.1353
# TRAINING Epoch: 352, Loss: 0.2364, Precision: 0.1350 , Recall: 0.1781
# TEST Epoch: 352, Precision: 0.0771 , Recall: 0.1353
# TRAINING Epoch: 353, Loss: 0.2342, Precision: 0.1370 , Recall: 0.1800
# TEST Epoch: 353, Precision: 0.0755 , Recall: 0.1320
# TRAINING Epoch: 354, Loss: 0.2353, Precision: 0.1396 , Recall: 0.1828
# TEST Epoch: 354, Precision: 0.0733 , Recall: 0.1287
# TRAINING Epoch: 355, Loss: 0.2354, Precision: 0.1409 , Recall: 0.1838
# TEST Epoch: 355, Precision: 0.0739 , Recall: 0.1287
# TRAINING Epoch: 356, Loss: 0.2375, Precision: 0.1420 , Recall: 0.1857
# TEST Epoch: 356, Precision: 0.0736 , Recall: 0.1287
# TRAINING Epoch: 357, Loss: 0.2373, Precision: 0.1465 , Recall: 0.1904
# TEST Epoch: 357, Precision: 0.0720 , Recall: 0.1254
# TRAINING Epoch: 358, Loss: 0.2363, Precision: 0.1477 , Recall: 0.1923
# TEST Epoch: 358, Precision: 0.0731 , Recall: 0.1254
# TRAINING Epoch: 359, Loss: 0.2362, Precision: 0.1490 , Recall: 0.1942
# TEST Epoch: 359, Precision: 0.0699 , Recall: 0.1188
# TRAINING Epoch: 360, Loss: 0.2345, Precision: 0.1504 , Recall: 0.1951
# TEST Epoch: 360, Precision: 0.0742 , Recall: 0.1254
# TRAINING Epoch: 361, Loss: 0.2362, Precision: 0.1511 , Recall: 0.1970
# TEST Epoch: 361, Precision: 0.0753 , Recall: 0.1287
# TRAINING Epoch: 362, Loss: 0.2343, Precision: 0.1521 , Recall: 0.1989
# TEST Epoch: 362, Precision: 0.0782 , Recall: 0.1353
# TRAINING Epoch: 363, Loss: 0.2356, Precision: 0.1538 , Recall: 0.2008
# TEST Epoch: 363, Precision: 0.0813 , Recall: 0.1419
# TRAINING Epoch: 364, Loss: 0.2362, Precision: 0.1538 , Recall: 0.1998
# TEST Epoch: 364, Precision: 0.0817 , Recall: 0.1419
# TRAINING Epoch: 365, Loss: 0.2336, Precision: 0.1582 , Recall: 0.2064
# TEST Epoch: 365, Precision: 0.0833 , Recall: 0.1452
# TRAINING Epoch: 366, Loss: 0.2365, Precision: 0.1613 , Recall: 0.2092
# TEST Epoch: 366, Precision: 0.0833 , Recall: 0.1452
# TRAINING Epoch: 367, Loss: 0.2359, Precision: 0.1634 , Recall: 0.2111
# TEST Epoch: 367, Precision: 0.0838 , Recall: 0.1452
# TRAINING Epoch: 368, Loss: 0.2357, Precision: 0.1646 , Recall: 0.2121
# TEST Epoch: 368, Precision: 0.0822 , Recall: 0.1419
# TRAINING Epoch: 369, Loss: 0.2371, Precision: 0.1650 , Recall: 0.2130
# TEST Epoch: 369, Precision: 0.0821 , Recall: 0.1419
# TRAINING Epoch: 370, Loss: 0.2368, Precision: 0.1668 , Recall: 0.2149
# TEST Epoch: 370, Precision: 0.0819 , Recall: 0.1419
# TRAINING Epoch: 371, Loss: 0.2341, Precision: 0.1681 , Recall: 0.2158
# TEST Epoch: 371, Precision: 0.0862 , Recall: 0.1485
# TRAINING Epoch: 372, Loss: 0.2359, Precision: 0.1674 , Recall: 0.2139
# TEST Epoch: 372, Precision: 0.0885 , Recall: 0.1518
# TRAINING Epoch: 373, Loss: 0.2386, Precision: 0.1705 , Recall: 0.2177
# TEST Epoch: 373, Precision: 0.0927 , Recall: 0.1584
# TRAINING Epoch: 374, Loss: 0.2347, Precision: 0.1710 , Recall: 0.2177
# TEST Epoch: 374, Precision: 0.0951 , Recall: 0.1617
# TRAINING Epoch: 375, Loss: 0.2335, Precision: 0.1712 , Recall: 0.2158
# TEST Epoch: 375, Precision: 0.0982 , Recall: 0.1650
# TRAINING Epoch: 376, Loss: 0.2340, Precision: 0.1760 , Recall: 0.2215
# TEST Epoch: 376, Precision: 0.1002 , Recall: 0.1650
# TRAINING Epoch: 377, Loss: 0.2356, Precision: 0.1769 , Recall: 0.2205
# TEST Epoch: 377, Precision: 0.1008 , Recall: 0.1650
# TRAINING Epoch: 378, Loss: 0.2369, Precision: 0.1778 , Recall: 0.2205
# TEST Epoch: 378, Precision: 0.1004 , Recall: 0.1617
# TRAINING Epoch: 379, Loss: 0.2352, Precision: 0.1802 , Recall: 0.2215
# TEST Epoch: 379, Precision: 0.1012 , Recall: 0.1617
# TRAINING Epoch: 380, Loss: 0.2351, Precision: 0.1815 , Recall: 0.2224
# TEST Epoch: 380, Precision: 0.1023 , Recall: 0.1617
# TRAINING Epoch: 381, Loss: 0.2333, Precision: 0.1837 , Recall: 0.2253
# TEST Epoch: 381, Precision: 0.1060 , Recall: 0.1683
# TRAINING Epoch: 382, Loss: 0.2347, Precision: 0.1857 , Recall: 0.2281
# TEST Epoch: 382, Precision: 0.1000 , Recall: 0.1584
# TRAINING Epoch: 383, Loss: 0.2376, Precision: 0.1855 , Recall: 0.2271
# TEST Epoch: 383, Precision: 0.1042 , Recall: 0.1650
# TRAINING Epoch: 384, Loss: 0.2352, Precision: 0.1888 , Recall: 0.2319
# TEST Epoch: 384, Precision: 0.1035 , Recall: 0.1650
# TRAINING Epoch: 385, Loss: 0.2375, Precision: 0.1895 , Recall: 0.2337
# TEST Epoch: 385, Precision: 0.1056 , Recall: 0.1683
# TRAINING Epoch: 386, Loss: 0.2375, Precision: 0.1920 , Recall: 0.2385
# TEST Epoch: 386, Precision: 0.1047 , Recall: 0.1683
# TRAINING Epoch: 387, Loss: 0.2356, Precision: 0.1941 , Recall: 0.2403
# TEST Epoch: 387, Precision: 0.1060 , Recall: 0.1683
# TRAINING Epoch: 388, Loss: 0.2342, Precision: 0.1951 , Recall: 0.2413
# TEST Epoch: 388, Precision: 0.1047 , Recall: 0.1683
# TRAINING Epoch: 389, Loss: 0.2348, Precision: 0.1971 , Recall: 0.2413
# ...
# TRAINING Epoch: 871, Loss: 0.2429, Precision: 0.5528 , Recall: 0.7992
# TEST Epoch: 871, Precision: 0.3108 , Recall: 0.5149
# TRAINING Epoch: 872, Loss: 0.2481, Precision: 0.5511 , Recall: 0.7983
# TEST Epoch: 872, Precision: 0.3091 , Recall: 0.5182
# TRAINING Epoch: 873, Loss: 0.2473, Precision: 0.5521 , Recall: 0.8040
# TEST Epoch: 873, Precision: 0.3126 , Recall: 0.5314
# TRAINING Epoch: 874, Loss: 0.2501, Precision: 0.5509 , Recall: 0.8058
# TEST Epoch: 874, Precision: 0.3108 , Recall: 0.5314
# TRAINING Epoch: 875, Loss: 0.2468, Precision: 0.5547 , Recall: 0.8030
# TEST Epoch: 875, Precision: 0.3041 , Recall: 0.5149
# TRAINING Epoch: 876, Loss: 0.2481, Precision: 0.5586 , Recall: 0.7992
# TEST Epoch: 876, Precision: 0.2980 , Recall: 0.5017
# TRAINING Epoch: 877, Loss: 0.2445, Precision: 0.5539 , Recall: 0.7945
# TEST Epoch: 877, Precision: 0.3012 , Recall: 0.5050
# TRAINING Epoch: 878, Loss: 0.2481, Precision: 0.5575 , Recall: 0.7955
# TEST Epoch: 878, Precision: 0.2988 , Recall: 0.4950
# TRAINING Epoch: 879, Loss: 0.2472, Precision: 0.5672 , Recall: 0.7992
# TEST Epoch: 879, Precision: 0.3051 , Recall: 0.4983
# TRAINING Epoch: 880, Loss: 0.2496, Precision: 0.5683 , Recall: 0.8040
# TEST Epoch: 880, Precision: 0.3101 , Recall: 0.5149
# TRAINING Epoch: 881, Loss: 0.2504, Precision: 0.5670 , Recall: 0.8021
# TEST Epoch: 881, Precision: 0.3030 , Recall: 0.5050
# TRAINING Epoch: 882, Loss: 0.2469, Precision: 0.5648 , Recall: 0.8011
# TEST Epoch: 882, Precision: 0.3074 , Recall: 0.5083
# TRAINING Epoch: 883, Loss: 0.2489, Precision: 0.5645 , Recall: 0.8002
# TEST Epoch: 883, Precision: 0.3016 , Recall: 0.5017
# TRAINING Epoch: 884, Loss: 0.2495, Precision: 0.5655 , Recall: 0.8011
# TEST Epoch: 884, Precision: 0.3030 , Recall: 0.5050
# TRAINING Epoch: 885, Loss: 0.2489, Precision: 0.5714 , Recall: 0.8068
# TEST Epoch: 885, Precision: 0.3052 , Recall: 0.5017
# TRAINING Epoch: 886, Loss: 0.2493, Precision: 0.5771 , Recall: 0.8077
# TEST Epoch: 886, Precision: 0.3126 , Recall: 0.4983
# TRAINING Epoch: 887, Loss: 0.2455, Precision: 0.5853 , Recall: 0.8049
# TEST Epoch: 887, Precision: 0.3093 , Recall: 0.4818
# TRAINING Epoch: 888, Loss: 0.2533, Precision: 0.5878 , Recall: 0.8106
# TEST Epoch: 888, Precision: 0.3087 , Recall: 0.4818
# TRAINING Epoch: 889, Loss: 0.2464, Precision: 0.5883 , Recall: 0.8162
# TEST Epoch: 889, Precision: 0.3042 , Recall: 0.4818
# TRAINING Epoch: 890, Loss: 0.2506, Precision: 0.5789 , Recall: 0.8162
# TEST Epoch: 890, Precision: 0.2988 , Recall: 0.4851
# TRAINING Epoch: 891, Loss: 0.2527, Precision: 0.5737 , Recall: 0.8143
# TEST Epoch: 891, Precision: 0.3012 , Recall: 0.4950
# TRAINING Epoch: 892, Loss: 0.2497, Precision: 0.5696 , Recall: 0.8172
# TEST Epoch: 892, Precision: 0.3026 , Recall: 0.5083
# TRAINING Epoch: 893, Loss: 0.2493, Precision: 0.5687 , Recall: 0.8153
# TEST Epoch: 893, Precision: 0.3056 , Recall: 0.5215
# TRAINING Epoch: 894, Loss: 0.2485, Precision: 0.5649 , Recall: 0.8162
# TEST Epoch: 894, Precision: 0.3059 , Recall: 0.5149
# TRAINING Epoch: 895, Loss: 0.2491, Precision: 0.5571 , Recall: 0.8143
# TEST Epoch: 895, Precision: 0.3069 , Recall: 0.5248
# TRAINING Epoch: 896, Loss: 0.2492, Precision: 0.5641 , Recall: 0.8134
# TEST Epoch: 896, Precision: 0.3110 , Recall: 0.5215
# TRAINING Epoch: 897, Loss: 0.2489, Precision: 0.5653 , Recall: 0.8115
# TEST Epoch: 897, Precision: 0.3126 , Recall: 0.5149
# TRAINING Epoch: 898, Loss: 0.2450, Precision: 0.5724 , Recall: 0.8200
# TEST Epoch: 898, Precision: 0.3133 , Recall: 0.5149
# TRAINING Epoch: 899, Loss: 0.2498, Precision: 0.5768 , Recall: 0.8209
# TEST Epoch: 899, Precision: 0.3160 , Recall: 0.5215
# TRAINING Epoch: 900, Loss: 0.2506, Precision: 0.5746 , Recall: 0.8200
# TEST Epoch: 900, Precision: 0.3173 , Recall: 0.5215
# TRAINING Epoch: 901, Loss: 0.2519, Precision: 0.5682 , Recall: 0.8162
# TEST Epoch: 901, Precision: 0.3104 , Recall: 0.5215
# TRAINING Epoch: 902, Loss: 0.2486, Precision: 0.5645 , Recall: 0.8162
# TEST Epoch: 902, Precision: 0.3043 , Recall: 0.5083
# TRAINING Epoch: 903, Loss: 0.2521, Precision: 0.5654 , Recall: 0.8143
# TEST Epoch: 903, Precision: 0.2990 , Recall: 0.4983
# TRAINING Epoch: 904, Loss: 0.2499, Precision: 0.5634 , Recall: 0.8162
# TEST Epoch: 904, Precision: 0.2984 , Recall: 0.4983
# TRAINING Epoch: 905, Loss: 0.2505, Precision: 0.5604 , Recall: 0.8181
# TEST Epoch: 905, Precision: 0.2938 , Recall: 0.4983
# TRAINING Epoch: 906, Loss: 0.2516, Precision: 0.5564 , Recall: 0.8228
# TEST Epoch: 906, Precision: 0.2940 , Recall: 0.5017
# TRAINING Epoch: 907, Loss: 0.2513, Precision: 0.5542 , Recall: 0.8190
# TEST Epoch: 907, Precision: 0.2996 , Recall: 0.5083
# TRAINING Epoch: 908, Loss: 0.2484, Precision: 0.5553 , Recall: 0.8181
# TEST Epoch: 908, Precision: 0.2946 , Recall: 0.5017
# TRAINING Epoch: 909, Loss: 0.2465, Precision: 0.5644 , Recall: 0.8219
# TEST Epoch: 909, Precision: 0.2969 , Recall: 0.5017
# TRAINING Epoch: 910, Loss: 0.2508, Precision: 0.5689 , Recall: 0.8209
# TEST Epoch: 910, Precision: 0.2982 , Recall: 0.4950
# TRAINING Epoch: 911, Loss: 0.2497, Precision: 0.5710 , Recall: 0.8266
# TEST Epoch: 911, Precision: 0.3042 , Recall: 0.5050
# TRAINING Epoch: 912, Loss: 0.2500, Precision: 0.5601 , Recall: 0.8256
# TEST Epoch: 912, Precision: 0.3027 , Recall: 0.5116
# TRAINING Epoch: 913, Loss: 0.2516, Precision: 0.5514 , Recall: 0.8238
# TEST Epoch: 913, Precision: 0.2955 , Recall: 0.5149
# TRAINING Epoch: 914, Loss: 0.2476, Precision: 0.5412 , Recall: 0.8228
# TEST Epoch: 914, Precision: 0.2881 , Recall: 0.5182
# TRAINING Epoch: 915, Loss: 0.2498, Precision: 0.5360 , Recall: 0.8200
# TEST Epoch: 915, Precision: 0.2880 , Recall: 0.5248
# TRAINING Epoch: 916, Loss: 0.2470, Precision: 0.5360 , Recall: 0.8200
# TEST Epoch: 916, Precision: 0.2785 , Recall: 0.5083
# TRAINING Epoch: 917, Loss: 0.2491, Precision: 0.5374 , Recall: 0.8190
# TEST Epoch: 917, Precision: 0.2776 , Recall: 0.5149
# TRAINING Epoch: 918, Loss: 0.2494, Precision: 0.5402 , Recall: 0.8162
# TEST Epoch: 918, Precision: 0.2802 , Recall: 0.5050
# TRAINING Epoch: 919, Loss: 0.2480, Precision: 0.5497 , Recall: 0.8181
# TEST Epoch: 919, Precision: 0.2852 , Recall: 0.5017
# TRAINING Epoch: 920, Loss: 0.2467, Precision: 0.5544 , Recall: 0.8162
# TEST Epoch: 920, Precision: 0.2843 , Recall: 0.4851
# TRAINING Epoch: 921, Loss: 0.2509, Precision: 0.5596 , Recall: 0.8181
# TEST Epoch: 921, Precision: 0.2852 , Recall: 0.4884
# TRAINING Epoch: 922, Loss: 0.2479, Precision: 0.5616 , Recall: 0.8247
# TEST Epoch: 922, Precision: 0.2888 , Recall: 0.4917
# TRAINING Epoch: 923, Loss: 0.2546, Precision: 0.5585 , Recall: 0.8275
# TEST Epoch: 923, Precision: 0.3020 , Recall: 0.5083
# TRAINING Epoch: 924, Loss: 0.2529, Precision: 0.5553 , Recall: 0.8275
# TEST Epoch: 924, Precision: 0.2975 , Recall: 0.5017
# TRAINING Epoch: 925, Loss: 0.2488, Precision: 0.5497 , Recall: 0.8228
# TEST Epoch: 925, Precision: 0.2967 , Recall: 0.5083
# TRAINING Epoch: 926, Loss: 0.2475, Precision: 0.5553 , Recall: 0.8275
# TEST Epoch: 926, Precision: 0.2918 , Recall: 0.4950
# TRAINING Epoch: 927, Loss: 0.2501, Precision: 0.5594 , Recall: 0.8256
# TEST Epoch: 927, Precision: 0.2978 , Recall: 0.4983
# TRAINING Epoch: 928, Loss: 0.2519, Precision: 0.5615 , Recall: 0.8256
# TEST Epoch: 928, Precision: 0.2948 , Recall: 0.4884
# TRAINING Epoch: 929, Loss: 0.2490, Precision: 0.5726 , Recall: 0.8322
# TEST Epoch: 929, Precision: 0.2978 , Recall: 0.4884
# TRAINING Epoch: 930, Loss: 0.2509, Precision: 0.5778 , Recall: 0.8294
# TEST Epoch: 930, Precision: 0.2932 , Recall: 0.4818
# TRAINING Epoch: 931, Loss: 0.2513, Precision: 0.5843 , Recall: 0.8266
# TEST Epoch: 931, Precision: 0.2964 , Recall: 0.4851
# TRAINING Epoch: 932, Loss: 0.2565, Precision: 0.5821 , Recall: 0.8256
# TEST Epoch: 932, Precision: 0.2931 , Recall: 0.4884
# TRAINING Epoch: 933, Loss: 0.2543, Precision: 0.5775 , Recall: 0.8256
# TEST Epoch: 933, Precision: 0.2959 , Recall: 0.4950
# TRAINING Epoch: 934, Loss: 0.2506, Precision: 0.5700 , Recall: 0.8285
# TEST Epoch: 934, Precision: 0.2871 , Recall: 0.4851
# TRAINING Epoch: 935, Loss: 0.2516, Precision: 0.5678 , Recall: 0.8285
# TEST Epoch: 935, Precision: 0.2922 , Recall: 0.4917
# TRAINING Epoch: 936, Loss: 0.2463, Precision: 0.5642 , Recall: 0.8285
# TEST Epoch: 936, Precision: 0.2938 , Recall: 0.4983
# TRAINING Epoch: 937, Loss: 0.2503, Precision: 0.5628 , Recall: 0.8275
# TEST Epoch: 937, Precision: 0.2981 , Recall: 0.5116
# TRAINING Epoch: 938, Loss: 0.2500, Precision: 0.5589 , Recall: 0.8275
# TEST Epoch: 938, Precision: 0.2987 , Recall: 0.5116
# TRAINING Epoch: 939, Loss: 0.2479, Precision: 0.5571 , Recall: 0.8275
# TEST Epoch: 939, Precision: 0.3000 , Recall: 0.5149
# TRAINING Epoch: 940, Loss: 0.2531, Precision: 0.5599 , Recall: 0.8275
# TEST Epoch: 940, Precision: 0.3066 , Recall: 0.5182
# TRAINING Epoch: 941, Loss: 0.2505, Precision: 0.5624 , Recall: 0.8238
# TEST Epoch: 941, Precision: 0.3051 , Recall: 0.5116
# TRAINING Epoch: 942, Loss: 0.2518, Precision: 0.5696 , Recall: 0.8256
# TEST Epoch: 942, Precision: 0.3043 , Recall: 0.5083
# TRAINING Epoch: 943, Loss: 0.2506, Precision: 0.5682 , Recall: 0.8247
# TEST Epoch: 943, Precision: 0.3057 , Recall: 0.5116
# TRAINING Epoch: 944, Loss: 0.2541, Precision: 0.5650 , Recall: 0.8238
# TEST Epoch: 944, Precision: 0.3008 , Recall: 0.5083
# TRAINING Epoch: 945, Loss: 0.2499, Precision: 0.5578 , Recall: 0.8228
# TEST Epoch: 945, Precision: 0.2915 , Recall: 0.4983
# TRAINING Epoch: 946, Loss: 0.2512, Precision: 0.5580 , Recall: 0.8247
# TEST Epoch: 946, Precision: 0.2887 , Recall: 0.4983
# TRAINING Epoch: 947, Loss: 0.2494, Precision: 0.5551 , Recall: 0.8313
# TEST Epoch: 947, Precision: 0.2953 , Recall: 0.5215
# TRAINING Epoch: 948, Loss: 0.2496, Precision: 0.5520 , Recall: 0.8351
# TEST Epoch: 948, Precision: 0.2994 , Recall: 0.5347
# TRAINING Epoch: 949, Loss: 0.2501, Precision: 0.5471 , Recall: 0.8313
# TEST Epoch: 949, Precision: 0.2937 , Recall: 0.5215
# TRAINING Epoch: 950, Loss: 0.2510, Precision: 0.5501 , Recall: 0.8285
# TEST Epoch: 950, Precision: 0.2891 , Recall: 0.5182
# TRAINING Epoch: 951, Loss: 0.2498, Precision: 0.5587 , Recall: 0.8294
# TEST Epoch: 951, Precision: 0.2868 , Recall: 0.5017
# TRAINING Epoch: 952, Loss: 0.2510, Precision: 0.5615 , Recall: 0.8266
# TEST Epoch: 952, Precision: 0.2876 , Recall: 0.5050
# TRAINING Epoch: 953, Loss: 0.2467, Precision: 0.5670 , Recall: 0.8332
# TEST Epoch: 953, Precision: 0.2860 , Recall: 0.4983
# TRAINING Epoch: 954, Loss: 0.2491, Precision: 0.5637 , Recall: 0.8379
# TEST Epoch: 954, Precision: 0.2828 , Recall: 0.4983
# TRAINING Epoch: 955, Loss: 0.2541, Precision: 0.5586 , Recall: 0.8398
# TEST Epoch: 955, Precision: 0.2857 , Recall: 0.5083
# TRAINING Epoch: 956, Loss: 0.2516, Precision: 0.5567 , Recall: 0.8379
# TEST Epoch: 956, Precision: 0.2881 , Recall: 0.5050
# TRAINING Epoch: 957, Loss: 0.2512, Precision: 0.5614 , Recall: 0.8445
# TEST Epoch: 957, Precision: 0.2884 , Recall: 0.5083
# TRAINING Epoch: 958, Loss: 0.2520, Precision: 0.5659 , Recall: 0.8454
# TEST Epoch: 958, Precision: 0.2996 , Recall: 0.5182
# TRAINING Epoch: 959, Loss: 0.2510, Precision: 0.5692 , Recall: 0.8417
# TEST Epoch: 959, Precision: 0.2884 , Recall: 0.5017
# TRAINING Epoch: 960, Loss: 0.2508, Precision: 0.5662 , Recall: 0.8379
# TEST Epoch: 960, Precision: 0.2955 , Recall: 0.5149
# TRAINING Epoch: 961, Loss: 0.2555, Precision: 0.5623 , Recall: 0.8332
# TEST Epoch: 961, Precision: 0.2952 , Recall: 0.5116
# TRAINING Epoch: 962, Loss: 0.2508, Precision: 0.5589 , Recall: 0.8313
# TEST Epoch: 962, Precision: 0.3008 , Recall: 0.5182
# TRAINING Epoch: 963, Loss: 0.2495, Precision: 0.5578 , Recall: 0.8322
# TEST Epoch: 963, Precision: 0.2914 , Recall: 0.5050
# TRAINING Epoch: 964, Loss: 0.2514, Precision: 0.5585 , Recall: 0.8322
# TEST Epoch: 964, Precision: 0.3030 , Recall: 0.5281
# TRAINING Epoch: 965, Loss: 0.2551, Precision: 0.5627 , Recall: 0.8369
# TEST Epoch: 965, Precision: 0.2949 , Recall: 0.5149
# TRAINING Epoch: 966, Loss: 0.2536, Precision: 0.5644 , Recall: 0.8388
# TEST Epoch: 966, Precision: 0.3042 , Recall: 0.5281
# TRAINING Epoch: 967, Loss: 0.2504, Precision: 0.5673 , Recall: 0.8426
# TEST Epoch: 967, Precision: 0.3071 , Recall: 0.5281
# TRAINING Epoch: 968, Loss: 0.2538, Precision: 0.5698 , Recall: 0.8464
# TEST Epoch: 968, Precision: 0.2983 , Recall: 0.5149
# TRAINING Epoch: 969, Loss: 0.2500, Precision: 0.5671 , Recall: 0.8483
# TEST Epoch: 969, Precision: 0.2958 , Recall: 0.5116
# TRAINING Epoch: 970, Loss: 0.2564, Precision: 0.5649 , Recall: 0.8454
# TEST Epoch: 970, Precision: 0.2901 , Recall: 0.5017
# TRAINING Epoch: 971, Loss: 0.2541, Precision: 0.5643 , Recall: 0.8483
# TEST Epoch: 971, Precision: 0.2996 , Recall: 0.5182
# TRAINING Epoch: 972, Loss: 0.2516, Precision: 0.5660 , Recall: 0.8483
# TEST Epoch: 972, Precision: 0.3027 , Recall: 0.5215
# TRAINING Epoch: 973, Loss: 0.2540, Precision: 0.5671 , Recall: 0.8483
# TEST Epoch: 973, Precision: 0.3023 , Recall: 0.5248
# TRAINING Epoch: 974, Loss: 0.2522, Precision: 0.5613 , Recall: 0.8464
# TEST Epoch: 974, Precision: 0.3023 , Recall: 0.5248
# TRAINING Epoch: 975, Loss: 0.2542, Precision: 0.5565 , Recall: 0.8454
# TEST Epoch: 975, Precision: 0.3034 , Recall: 0.5347
# TRAINING Epoch: 976, Loss: 0.2532, Precision: 0.5507 , Recall: 0.8445
# TEST Epoch: 976, Precision: 0.3050 , Recall: 0.5446
# TRAINING Epoch: 977, Loss: 0.2498, Precision: 0.5552 , Recall: 0.8483
# TEST Epoch: 977, Precision: 0.3121 , Recall: 0.5512
# TRAINING Epoch: 978, Loss: 0.2508, Precision: 0.5567 , Recall: 0.8417
# TEST Epoch: 978, Precision: 0.3068 , Recall: 0.5347
# TRAINING Epoch: 979, Loss: 0.2544, Precision: 0.5673 , Recall: 0.8464
# TEST Epoch: 979, Precision: 0.2904 , Recall: 0.4983
# TRAINING Epoch: 980, Loss: 0.2538, Precision: 0.5762 , Recall: 0.8445
# TEST Epoch: 980, Precision: 0.2854 , Recall: 0.4785
# TRAINING Epoch: 981, Loss: 0.2531, Precision: 0.5779 , Recall: 0.8492
# TEST Epoch: 981, Precision: 0.2885 , Recall: 0.4884
# TRAINING Epoch: 982, Loss: 0.2549, Precision: 0.5707 , Recall: 0.8483
# TEST Epoch: 982, Precision: 0.2846 , Recall: 0.4818
# TRAINING Epoch: 983, Loss: 0.2549, Precision: 0.5638 , Recall: 0.8492
# TEST Epoch: 983, Precision: 0.2830 , Recall: 0.4950
# TRAINING Epoch: 984, Loss: 0.2511, Precision: 0.5585 , Recall: 0.8464
# TEST Epoch: 984, Precision: 0.2790 , Recall: 0.4917
# TRAINING Epoch: 985, Loss: 0.2537, Precision: 0.5542 , Recall: 0.8483
# TEST Epoch: 985, Precision: 0.2717 , Recall: 0.4851
# TRAINING Epoch: 986, Loss: 0.2534, Precision: 0.5476 , Recall: 0.8454
# TEST Epoch: 986, Precision: 0.2739 , Recall: 0.4917
# TRAINING Epoch: 987, Loss: 0.2495, Precision: 0.5493 , Recall: 0.8454
# TEST Epoch: 987, Precision: 0.2722 , Recall: 0.4851
# TRAINING Epoch: 988, Loss: 0.2559, Precision: 0.5612 , Recall: 0.8511
# TEST Epoch: 988, Precision: 0.2732 , Recall: 0.4851
# TRAINING Epoch: 989, Loss: 0.2552, Precision: 0.5675 , Recall: 0.8520
# TEST Epoch: 989, Precision: 0.2884 , Recall: 0.5083
# TRAINING Epoch: 990, Loss: 0.2537, Precision: 0.5631 , Recall: 0.8492
# TEST Epoch: 990, Precision: 0.2924 , Recall: 0.5182
# TRAINING Epoch: 991, Loss: 0.2549, Precision: 0.5585 , Recall: 0.8464
# TEST Epoch: 991, Precision: 0.2916 , Recall: 0.5149
# TRAINING Epoch: 992, Loss: 0.2524, Precision: 0.5490 , Recall: 0.8445
# TEST Epoch: 992, Precision: 0.2952 , Recall: 0.5281
# TRAINING Epoch: 993, Loss: 0.2565, Precision: 0.5428 , Recall: 0.8426
# TEST Epoch: 993, Precision: 0.2967 , Recall: 0.5347
# TRAINING Epoch: 994, Loss: 0.2550, Precision: 0.5470 , Recall: 0.8454
# TEST Epoch: 994, Precision: 0.2870 , Recall: 0.5182
# TRAINING Epoch: 995, Loss: 0.2489, Precision: 0.5516 , Recall: 0.8464
# TEST Epoch: 995, Precision: 0.2823 , Recall: 0.5050
# TRAINING Epoch: 996, Loss: 0.2507, Precision: 0.5542 , Recall: 0.8483
# TEST Epoch: 996, Precision: 0.2815 , Recall: 0.5083
# TRAINING Epoch: 997, Loss: 0.2549, Precision: 0.5547 , Recall: 0.8464
# TEST Epoch: 997, Precision: 0.2812 , Recall: 0.5050
# TRAINING Epoch: 998, Loss: 0.2535, Precision: 0.5559 , Recall: 0.8435
# TEST Epoch: 998, Precision: 0.2839 , Recall: 0.5116
# TRAINING Epoch: 999, Loss: 0.2538, Precision: 0.5530 , Recall: 0.8464
# TEST Epoch: 999, Precision: 0.2849 , Recall: 0.5182

# %% [markdown]
# Save output

# %%
all_matches[998]

# %%
version = 'V213'
case = "case_a"

# %%
import pickle

# %%
with open("/content/gdrive/My Drive/1_Studium/2_Master/Master Thesis/2_Projekt/Scratch/all_in/MAGNET/results/trainings/GCN/wrong_sets_left_" + version + "_" + case , "wb") as fp:   #Pickling
        pickle.dump(wrong_sets_left_train, fp)

# %%
with open("/content/gdrive/My Drive/1_Studium/2_Master/Master Thesis/2_Projekt/Scratch/all_in/MAGNET/results/trainings/GCN/wrong_sets_right_" + version + "_" + case,"wb") as fp:   #Pickling
        pickle.dump(wrong_sets_right_train, fp)

# %%
with open("/content/gdrive/My Drive/1_Studium/2_Master/Master Thesis/2_Projekt/Scratch/all_in/MAGNET/results/trainings/GCN/matches" + version + "_" + case, "wb") as fp:   #Pickling
        pickle.dump(all_matches, fp)

# %%
#with open("/content/gdrive/My Drive/1_Studium/2_Master/Master Thesis/2_Projekt/Scratch/all_in/MAGNET/results/trainings/GCN/macheinfach.pt", "wb") as fp:   #Pickling
 #       pickle.dump(output, fp)

# %%
#torch.save(output, "/content/gdrive/My Drive/1_Studium/2_Master/Master Thesis/2_Projekt/Scratch/all_in/MAGNET/results/trainings/GCN/macheinfach#")

# %%
model_name = 'GCNConv'
#helper_funcs.save_training_verlauf(losses, precisions, recalls,
#                      precision_tests, recall_tests,
#                      use_case, a_or_b, model_name, version)

# %%
track = "anatomy_diff"

# %%
df = pd.DataFrame(list(zip(losses, precisions, recalls, precision_tests, recall_tests)), columns =['losses', 'precisions_train', 'recalls_train', 'precisions_test', 'recalls_test'])

# %%
path = "/content/gdrive/My Drive/1_Studium/2_Master/Master Thesis/2_Projekt/Scratch/all_in/MAGNET/results/trainings/GCN/" + track + "_" + case + "_" + model_name + "_" + version
df.to_csv(path + ".csv")
