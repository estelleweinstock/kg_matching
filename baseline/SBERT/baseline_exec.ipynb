# %% [markdown]
# # SBERT-based baseline

# %% [markdown]
# In this notebook, we test how well the initial embeddings without further learning are

# %% [markdown]
# ## Imports & Data

# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Mounted at /content/gdrive/

# %%
import os
import torch
os.environ['TORCH'] = torch.__version__
print(torch.__version__)

# !pip install -q torch-scatter -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install -q torch-sparse -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install -q git+https://github.com/pyg-team/pytorch_geometric.git

# %%
# !pip install sentence_transformers

# %%
from sentence_transformers import SentenceTransformer, util

# %%
# load dataset
file_path = "/content/gdrive/My Drive/1_Studium/2_Master/Master Thesis/2_Projekt/Scratch/all_in/data/anatomy/"
data = torch.load(file_path+"case_a.pt")

# %%
os.chdir("/content/gdrive/My Drive/1_Studium/2_Master/Master Thesis/2_Projekt/Scratch/all_in/MAGNET")

# %% [markdown]
# ## Precision, Recall & F-Measure

# %%
from models.helpers import calc_prec_rec

# %%
gold_standard = list(map(list, zip(data.left_indices.tolist(), data.right_indices.tolist())))

# %%
def f_measure(Precision, Recall):
   return (2 * Precision * Recall) / (Precision + Recall)

# %%
prec, rec, matches = calc_prec_rec(data.x_one, data.x_two, gold_standard, 0.9)
