# %% [markdown]
# # Plot results of GCN Align with anatomy

# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Mounted at /content/gdrive/

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
pip install openpyxl
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import seaborn as sns

# %%
PATH = "/content/gdrive/My Drive/1_Studium/2_Master/Master Thesis/2_Projekt/Scratch/all_in/MAGNET/baseline/GCN-Align_with_anatomy/"

# %%
df = pd.read_excel(PATH +'Loss GCN-Align.xlsx',header=None)

# %%
plt.figure(figsize=(14, 6), dpi=80)

ax = sns.lineplot(data=df[[1, 2]], palette=['b', 'g'], linewidth=0.5, dashes=False)
plt.legend(labels=["Attributional Loss","Structural Loss"],fontsize=18)
ax.set(xlabel='Epochs', ylabel='Loss')
ax.yaxis.get_label().set_fontsize(20)
ax.xaxis.get_label().set_fontsize(20)
ax.tick_params(axis="x", labelsize=15)
ax.tick_params(axis="y", labelsize=15)
plt.show()

# %%
df
# Out:
#                              0        1        2
# 0    Epoch: 0001 AE_train_loss  3.17720  2.85934
# 1    Epoch: 0002 AE_train_loss  2.99273  2.31080
# 2    Epoch: 0003 AE_train_loss  2.96130  1.41808
# 3    Epoch: 0004 AE_train_loss  2.94948  1.02473
# 4    Epoch: 0005 AE_train_loss  2.94327  0.81531
# ..                         ...      ...      ...
# 995  Epoch: 0996 AE_train_loss  2.87895  0.05358
# 996  Epoch: 0997 AE_train_loss  2.87891  0.05169
# 997  Epoch: 0998 AE_train_loss  2.87895  0.05025
# 998  Epoch: 0999 AE_train_loss  2.87892  0.04889
# 999  Epoch: 1000 AE_train_loss  2.87890  0.04778
#
# [1000 rows x 3 columns]
